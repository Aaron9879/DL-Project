# %% [markdown]
# Group Name: Anonymous
#
# Group members:
#
# - Shuang Jie Zhu 33432457
#
# - Kaicheng Huang 34253572
#
# - Yuhang Peng 34278818
#
# - Jingmin Zhu 34265597

# %% [markdown]
# # FIT5226 Project
#
# ## Stage 2 - Deep Q-Learning
# ***

# %% [markdown]
# ### 1. Imports

# %% [markdown]
# Two libraries (`numpy`, `matplotlib`) and one module (`random`) are utilised for stage 1 of the project.

# %%
# Use the TkAgg backend in matplotlib to display both plots and animations.
import matplotlib
matplotlib.use('TkAgg')

# %%
# Importing the required libraries
import numpy as np
import random
import torch
import copy
import time
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import ListedColormap
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ***

# %% [markdown]
# ### 2. Environment Setup

# %% [markdown]
# ##### **Environment description**
#
# A single agent operates within a grid environment where the task is to pick up the item at a randomly determined location $A$ and deliver it to a target location $B$, which is also randomly determined for each episode. The grid world is defined as a square grid of size $n \times n$, with $n$ being a parameterisable dimension with a default value of 4. The agent begins at a random location on the grid and must navigate to the item location $A$, pick it up and then deliver it to the target location $B$. During this process, the agent can also observe both the item and target locations.
#
# ##### **Assumptions for initial agent, item and target locations**
# - Item location cannot be the same as initial agent location.
# - Item location cannot be the same as target location.
#
# ##### **State space**
#
# The state space in the current Deep-Q Learning implementation is richer compared to the previous Q-table setup. The agent's state space includes the following components:
#
# 1. **Agent location**: The current position of the agent on the grid, which is represented as a tuple of coordinates $(y_{agent},x_{agent})$.
# 2. **Item location**: The location of the item on the grid, which is represented as a tuple of coordinates $(y_{item},x_{item})$.
# 3. **Target location**: The location of the target on the grid, which is represented as a tuple of coordinates $(y_{target},x_{target})$.
# 4. **Directions**: The relative directions from the agent to both the item and the target, represented as two vectors $(\Delta y_{item},\Delta x_{item})$ and $(\Delta y_{target},\Delta x_{target})$. The relative direction is calculated as either item or target location minus agent location.
# 5. **Item possession status**: A boolean value indicates whether the agent has picked up the item, which is represent by a boolean variable $has\_item$.
#
# Thus, the complete state of the environment can be represented as a tuple $\left((y_{agent},x_{agent}),(y_{item},x_{item}),(y_{target},x_{target}),(\Delta y_{item},\Delta x_{item}),(\Delta y_{target},\Delta x_{target}),has\_item\right)$.
#
# ##### **Action space**
#
# The agent has four actions that it can execute:
# - **Move north**: The agent attempts to move one cell upwards on the grid.
# - **Move south**: The agent attempts to move one cell downwards on the grid.
# - **Move west**: The agent attempts to move one cell to the left on the grid.
# - **Move east**: The agent attempts to move one cell to the right on the grid.
#
# These actions are executed with boundary checks to ensure that the agent does not move outside the grid.
#
# ##### **Reward structure**
#
# In reinforcement learning, the reward structure is designed to encourage the agent to complete the task of picking up the item at location $A$ and delivering it to location $B$ efficiently. The reward structure is designed as follows:
#
# - **Step penalty**: The agent receives a penalty of -1 for each step it takes. This encourages the agent to complete the task in as few steps as possible.
# - **Hit-wall penalty**: The agent receives a penalty of -5 for each time it hits a wall. This encourages the agent not to get out the grid.
# - **Item pickup**: When the agent successfully reaches the item location $A$ and picks up the item, it continues to receive the step penalty of -1. No additional reward is given for picking up the item as it is part of the task. A small reward can be given to the agent in a practical application, which is not applied in the current setting.
# - **Task completion**: The agent receives a reward of +100 upon successfully deliverying the item to the target location $B$, which indicates the completion of the task.
#
# The environment and reward structure are set up to reinforce the agent's learning of an optimal policy that minimise the number of steps taken to complete the task. The agent need balance between exploring the grid to find the item and exploiting its knowledge to arrive the target location as quickly as possible once the item being picked up.
#
# The environment is implemented in Python as a class `GridWorld`, which supports grids of arbitrary size. The grid size, preset agent location, preset item location and rpeset target locations are parameterised, allowing the environment to be easily adapted to different scenarios. The movements of the agent are controlled through the `step` function, which updates the environment based on the action taken and returns the new state, the reward for the action and a boolean value indicating whether the task is completed. The environment also includes a `reset` function, which randomises the agent, item and target locations, allowing the agent to start the task with different initial agent location, item location and target location, promoting generalisation during its learning process.
#
# This setup provides a clear and efficient framework for the agent to learn the task of picking up and transporting an item within a grid world environment. The reward structure is designed to be simple yet effective, encouraging the agent to learn an optimal path from any starting position to the target location via the item location. The flexibility of the design of the environment allows for easy adjustments to grid size and task complexity, making it a robust foundation for further experimentation and learning in reinforcement learning tasks.

# %%
class GridWorld:
	# Initialise the size of the grid world and the locations of the agent, item, and target based on the parameter given_location
	def __init__(self, size=4, preset_agent_location=(4, 0), preset_item_location=(0, 4), preset_target_location=(4,4), given_location=False):
		self.size = size
		if not given_location:
			self.reset()
		else:
			self.agent_location = preset_agent_location
			self.item_location = preset_item_location
			self.target_location = preset_target_location
			self.has_item = False

	# Reset the environment by randomly placing the agent, item, and target in the grid world
	def reset(self):
		# Randomly place the agent and target locations in the grid world
		self.agent_location = self._random_position()
		self.target_location = self._random_position()
        
		# Randomly place the item location in the grid world while ensuring it is not the same as the initial agent or target location
		self.item_location = self._random_position()
		while self.item_location == self.target_location or self.item_location == self.agent_location:
			self.item_location = self._random_position()

		# Reset the has_item flag to False
		self.has_item = False
		return self._get_state()

	# Randomly generate a position in the grid world
	def _random_position(self):
		return (random.randint(0, self.size-1), random.randint(0, self.size-1))

	# Get the current state of the environment
	def _get_state(self):
		# Calculate the direction to the item and the target from the agent's location
		direction_to_item = (self.item_location[0] - self.agent_location[0], self.item_location[1] - self.agent_location[1])
		direction_to_target = (self.target_location[0] - self.agent_location[0], self.target_location[1] - self.agent_location[1])

		# Return the state including the directions
		return np.array([*self.agent_location, *self.item_location, *self.target_location, *direction_to_item, *direction_to_target, int(self.has_item)])

	# Step the environment by taking an action
	def step(self, action):
		action_map = ['north', 'south', 'west', 'east']
		y, x = self.agent_location

		if action_map[action] == 'north':
			new_y, new_x = y - 1, x
		elif action_map[action] == 'south':
			new_y, new_x = y + 1, x
		elif action_map[action] == 'west':
			new_y, new_x = y, x - 1
		elif action_map[action] == 'east':
			new_y, new_x = y, x + 1
		else:
			raise ValueError("Invalid action!")

		# Check if the new position is within the grid world
		if 0 <= new_x < self.size and 0 <= new_y < self.size:
			self.agent_location = (new_y, new_x)
			wall_hit = False
		else:
			wall_hit = True

		# Calculate the reward based on the new state
		if not self.has_item and self.agent_location == self.item_location:
			reward = -1
			self.has_item = True
		elif self.has_item and self.agent_location == self.target_location:
			reward = 100
			done = True
			return self._get_state(), reward, done
		elif wall_hit:
			reward = -5
		else:
			reward = -1

		done = False
		return self._get_state(), reward, done

# %% [markdown]
# ***

# %% [markdown]
# ### 3. Deep Q-Learning Algorithm

# %% [markdown]
# In this task, a Deep Q-Learning (DQL) algorithm is implemented in a Python class `DeepQAgent` to enable the agent to complete a transport task in a grid world environment. DQL is a model-free reinfrocement learning algorithm that approximates the Q-value function using a neural network. The aim is to learn the optimal action-selection policy by learning the action-value function $Q(S,A)$, where $S$ and $A$ represent the state and action, respectively. The DQL learns to estimate the expected cumulative reward for taking action $A$ in state $S$ and following the optimal policy thereafter, but instead of using a Q-table, a neural network is used to approximate Q-values.
#
# ##### **Key components**
#
# 1. **Initialisation**:
#
# The agent is initialised with several key parameters:
#
# - `state_size`: the size of the state space, which includes the agent location, item location, target location, relative directions and possession status.
#
# - `action_size`: the number of possible actions, e.g., move north, south, west and east.
#
# - `gamma`: the discount factor, which controls the importance and relevance of the future rewards.
#
# - `epsilon`: the exploration rate, determining the probability of choosing a random action.
#
# - `epsilon_decay`: the rate at which the exploration rate decays after each episode.
#
# - `min_epsion`: the minimum value for the exploration rate.
#
# - `replay_buffer_size`: the size of the replay buffer used to store past experience.
#
# - `batch_size`: the size of the mini-batch sampled from the replay buffer during training.
#
# - `lr`: the learning rate for the optimizer.
#
# - `copy_freq`: the frequency with which the target network is updated.
#
# Importantly, the agent has two neural networks, namely the prediction network, which is used to choose actions during training and the target network, which is used to compute the target Q-value. The target network is a copy of the prediction network and is periodically updated to stablise training.
#
# 2. **Neural network preparation**:
#
# the funciton `prepare_torch` constructs the neural networks using PyTorch. The network is a simple feed-forward neural network with two hidden layers of 150 and 100 neurons, both followed by ReLU activation functions. The output layer has a size equal to the action space (i.e., move north, south, west, east). The agent uses two networks:
#
# - `model`: the main Q-network that is updated during training.
# - `model2`: the target network, which is a copy of `model` and is updated periodically.
#
# The loss function is the mean squared error (MSE) and the optimizer is Adam.
#
# 3. ***Action selection*
#
# The function `get_action` is responsible for selecting actions using an $\epsilon$-greedy policy. With probability $\epsilon$, the agent selects a random action (exploration). Otherwise, the agent exploits its current knowledge by selecting the action with the maximum Q-value. The Q-values for the current state are obtained from the prediction network (`model`) by passing the state through the network and selecting the action with the maximum Q-value.
#
# 4. **Experience replay**
#
# The agent uses a replay buffer to store past experiences in the form of tuples (state, action, reward, next_state, done). The function `remember` stores these experiences in the buffer. If the buffer exceeds its maximum capacity, the oldest experiences are removed.
#
# During training, a mini-batch of experiences is randomly sampled from the replay buffer. This experience replay mechanism helps break correlations between consecutive experiences and stabilises learning.
#
# 5. **Q-value updates and training**
#
# The function `train_one_step` is responsible for updating the Q-values. The agent uses the sampled mini-batch to compute target Q-values and updates the prediction network. The target Q-value for a given transition is computed as:
#
# \begin{equation}
# target = R + \gamma \max\limits_{A'} Q(S', A')，
# \end{equation}
#
# where $R$ is the reward, $\gamma$ is the discount factor, and $Q(S', A')$ is the maximum predicted Q-value for the next state $S'$.
#
# If the next state is terminal, the Q-value update is based solely on the immediate reward $R$. The agent uses backpropagation to minimise the loss between the predicted Q-values and the target Q-values using the Adam optimizer.
#
# The target network is periodically updated to match the prediction network every `copy_freq` steps, ensuring that the training remains stable.
#
# 6. **Exploration rate decay**
#
# The function `decay_epsilon` gradually decreases the exploration rate $\epsilon$ after each episode. The rate decays multiplicatively by the factor `epsilon_decay`, and it is clamped to a minimum value `min_epsilon`. This allows the agent to transition from exploration to exploitation as it gains more knowledge of the environment.
#
# The DQL algorithm implemented in the DeepQAgent class enables the agent to efficiently learn the optimal policy for completing the transport task in the grid world environment. Through the use of neural networks to approximate Q-values, the agent is able to handle larger and more complex state spaces than the table-based Q-learning algorithm. The combination of experience replay, target networks, and exploration decay allows the agent to balance exploration and exploitation, improving the stability and efficiency of learning.

# %%
# Implement the Deep Q-Learning algorithm
class DeepQAgent:
	# Initialise the agent with the state size, action size, and other hyperparameters
	def __init__(self, state_size, action_size, gamma=0.95, epsilon=1.0, epsilon_decay=0.995,
                 min_epsilon=0.1, replay_buffer_size=1000, batch_size=200, lr=0.001, copy_freq=500):
		# Initialize parameters
		self.state_size = state_size  # State size
		self.action_size = action_size  # Number of possible actions, e.g., 4 directions
		self.gamma = gamma  # Discount factor
		self.epsilon = epsilon  # Exploration rate
		self.epsilon_decay = epsilon_decay  # Decay factor for epsilon
		self.min_epsilon = min_epsilon  # Minimum epsilon for exploration
		self.batch_size = batch_size  # Mini-batch size for training
		self.lr = lr  # Learning rate for the optimizer
		self.copy_freq = copy_freq  # Frequency to update the target network

		# Step counter for updating the target network
		self.steps = 0

		# Experience replay buffer
		self.replay_buffer = []
		self.replay_buffer_size = replay_buffer_size

		# Initialise the Q-networks (prediction and target)
		self.model, self.model2, self.optimizer, self.loss_fn = self.prepare_torch()

	# Prepare the neural network model using PyTorch
	def prepare_torch(self):
		model = torch.nn.Sequential(
            torch.nn.Linear(self.state_size, 150),
            torch.nn.ReLU(),
            torch.nn.Linear(150, 100),
            torch.nn.ReLU(),
            torch.nn.Linear(100, self.action_size)
        )
		model2 = copy.deepcopy(model)  # Target network is a copy of the prediction network
		model2.load_state_dict(model.state_dict())

        # Define loss function and optimizer with the given learning rate
		loss_fn = torch.nn.MSELoss()
		optimizer = torch.optim.Adam(model.parameters(), lr=self.lr)

		return model, model2, optimizer, loss_fn

	# Update the target network with the prediction network
	def update_target(self):
		self.model2.load_state_dict(self.model.state_dict())

	# Get the Q-values for a given state
	def get_qvals(self, state):
		state_tensor = torch.from_numpy(state).float().unsqueeze(0)  # Unsqueeze to add batch dimension
		qvals_torch = self.model(state_tensor)
		return qvals_torch.detach().numpy()

	# Get the maximum Q-value for a given state
	def get_maxQ(self, next_state):
		state_tensor = torch.from_numpy(next_state).float().unsqueeze(0)  # Unsqueeze to add batch dimension
		return torch.max(self.model2(state_tensor)).item()

	# Get the action based on the epsilon-greedy policy
	def get_action(self, state):
		if random.uniform(0, 1) < self.epsilon:
			return random.choice([0, 1, 2, 3])  # Exploration with a random action
		else:
			qvals = self.get_qvals(state)
			return np.argmax(qvals)  # Exploitation with the best action based on Q-values

	# Store the experience in the replay buffer
	def remember(self, state, action, reward, next_state, done):
		self.replay_buffer.append((state, action, reward, next_state, done))
		if len(self.replay_buffer) > self.replay_buffer_size:
			self.replay_buffer.pop(0)

    # Optimised train_one_step function
	def train_one_step(self, states, actions, targets):
		# Convert lists of NumPy arrays to a single NumPy array
		states = np.array(states)
		actions = np.array(actions)
		targets = np.array(targets)

		# Convert data to tensors
		state_batch = torch.tensor(states, dtype=torch.float32)
		action_batch = torch.tensor(actions, dtype=torch.long)
		target_batch = torch.tensor(targets, dtype=torch.float32)

		# Get Q-values from the model for the current states
		qvals = self.model(state_batch)
		predicted_qvals = qvals.gather(1, action_batch.unsqueeze(1)).squeeze()

		# Compute the loss (TD error)
		loss = self.loss_fn(predicted_qvals, target_batch)

		# Backpropagation and optimization step
		self.optimizer.zero_grad()
		loss.backward()
		self.optimizer.step()

		return loss.item()

	# Train the agent using the experience replay buffer
	def train(self):
		# Wait until we have enough samples for a full mini-batch
		if len(self.replay_buffer) < self.batch_size:
			return
        
        # Sample a mini-batch from the replay buffer
		minibatch = random.sample(self.replay_buffer, self.batch_size)
		states, actions, rewards, next_states, dones = zip(*minibatch)

        # Compute TD-targets for each transition in the mini-batch
		targets = []
		for i in range(len(minibatch)):
			# If the episode has ended, the target is the reward otherwise the reward plus the discounted maximum Q-value
			if dones[i]:
				target = rewards[i]
			else:
				next_maxQ = self.get_maxQ(next_states[i])
				target = rewards[i] + self.gamma * next_maxQ
			targets.append(target)

		# Perform training on the mini-batch
		loss = self.train_one_step(states, actions, targets)

		# Update the target network every 'copy_freq' steps
		self.steps += 1
		if self.steps % self.copy_freq == 0:
			self.update_target()

		return loss

	# Decay the epsilon value after each episode
	def decay_epsilon(self):
		self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)

# %% [markdown]
# ***

# %% [markdown]
# ### 4. Training Phase
#
# The training process is implemented in the function `train_agent`, which trains the agent over a default of 1000 episodes. This Deep Q-Learning implementation leverages a neural network to approximate Q-values.
#
# ##### **Key components**
#
# 1. **Episode initialisation**:
#
# At the start of each episode, the environment is reset using the `env.reset()` method, which randomises the initial agent, item, and target locations. The reset method returns the initial state of the environment. A boolean variable `done` is initialised to False, indicating that the episode is not yet finished. Additionally, a step counter (`steps`) is set to 0 to track the number of actions taken by the agent within the episode.
#
# 2. **Agent-environment interaction**:
#
# Within each episode, the agent interacts with the environment by selecting actions and observing their effects. The loop continues until either the task is completed (the item is delivered to the target location) or the maximum allowed number of steps (`max_steps`, set to 100) is reached.
#
# The agent selects an action using the `agent.get_action(state)` method, which follows an $\epsilon$-greedy policy. This balances exploration (random action selection) and exploitation (selecting the action with the highest predicted Q-value based on the current state). The chosen action is then executed in the environment using `env.step(action)`, which returns the next state, the reward, and whether the episode is done.
#
# 3. **Q-value update**:
#
# After each action, the agent stores the transition (state, action, reward, next state, done) in its experience replay buffer using the `agent.remember(state, action, reward, next_state, done)` method. If the replay buffer has enough samples (i.e., it contains at least `batch_size` experiences), the agent samples a mini-batch from the buffer and trains its neural network by updating the predicted Q-values using the `agent.train()` method.
#
# The loss is computed as the difference between the predicted Q-values and the target Q-values (computed using the target network). Backpropagation is applied to minimize this loss and update the prediction network.
#
# 4. **Target network update**:
#
# Every `update_freq` steps, the agent updates its target network by copying the weights from the prediction network. This is done using the `agent.update_target()` method to improve training stability. The target network is used to calculate target Q-values for training but is updated less frequently to avoid rapid changes that could destabilize learning.
#
# 5. **Exploration rate decay**:
#
# After each episode, the agent’s exploration rate $\epsilon$ is decayed using the `agent.decay_epsilon()` method. This gradual reduction in exploration rate ensures that the agent transitions from exploration (trying out new actions) to exploitation (using learned policies) as training progresses. The decay factor is controlled by the `epsilon_decay` parameter, and the exploration rate is capped at a minimum value `min_epsilon`.
#
# 6. **Episode termination**:
#
# An episode can terminate either when the agent successfully delivers the item to the target location, or when the step count reaches `max_steps` (defaulted to 100). If the agent does not complete the task within the step limit, the episode ends without any additional penalties, and the agent moves to the next episode.
#
# 7. **Progress monitoring**:
#
# The training process is monitored by printing the progress after every 100 episodes or at the end of the training based on the parameter `verbose`. The printed message includes the episode number, the time elapsed since the last update, and the current exploration rate $\epsilon$. This helps in tracking the agent’s training progress and the decay of the exploration rate over time.

# %%
# Implement the training function for the agent
def train_agent(agent, env, episodes=1000, max_steps=100, update_freq=5, verbose=True):
    # record the start time
    start_time = time.time()
    
	# Iterate over episodes to train the agent
    for episode in range(episodes):
        # Reset the environment for each new episode
        state = env.reset()
        done = False
        total_loss = 0
        steps = 0

        # Agent continues until the task is finished or the step limit is reached
        # No penalty for exceeding the step limit, just terminate the episode as it is not a successful one
        while not done and steps < max_steps:
            action = agent.get_action(state)  # Agent chooses an action
            next_state, reward, done = env.step(action)  # Execute the action in the environment
            
            # Store the experience in the replay buffer
            agent.remember(state, action, reward, next_state, done)
            
            # Perform training if enough samples are available in the replay buffer
            if len(agent.replay_buffer) >= agent.batch_size:
                loss = agent.train()
                total_loss += loss

            # update the target network every 'update_freq' steps to stabilise learning
            if steps % update_freq == 0:
                agent.update_target()
            
            # Update to the next state
            state = next_state
            steps += 1
        
        # Decay the exploration rate after each episode
        agent.decay_epsilon()

        # Print progress
        if verbose and (episode + 1) % 100 == 0 or episode == episodes - 1:
            end_time = time.time()
            elapsed_time = end_time - start_time
            print(f'Episode {episode + 1}/{episodes} completed ({elapsed_time:.2f}s), epsilon: {agent.epsilon:.3f}')
            start_time = time.time()

# %% [markdown]
# ***

# %% [markdown]
# ### 5. Evaluation Phase

# %% [markdown]
# #### **Introduction**
# In this project, our goal is to implement a tabular Q-learning algorithm to enable an agent to effectively complete a specified task in a grid world environment. The agent's task is to start from a random position, pick up an item located at point A, and deliver it to point B. To evaluate the agent's learning and generalization abilities, we designed two tests: the first test assesses the model's performance with different numbers of training episodes, the second test evaluates the performance of a model trained extensively across all possible initial states.
#
# Our objectives in conducting these tests are as follows:
#
# ##### **1. Verifying the model's learning ability**
# - **Objective**: Through the first test, we can verify the model's learning ability under different training conditions. Theoretically, as the number of training episodes increases, the model should be able to better learn the optimal strategy for completing the task.
#
# - **Expected outcome**: By analysing the success rate, average steps, average reward, and deviation from the optimal strategy, we can verify whether increasing the training episodes indeed leads to improved performance. If the test results show improvement in these metrics as the number of training episodes increases, it indicates that the model's learning ability has been enhanced.
#
# ##### **2. Verifying the model's generalisation ability**
# - **Objective**: Through the second test, we can verify the performance of the trained model under different initial conditions.
#
# - **Expected outcome**: If the test results show that the model maintains a high success rate and low average steps and deviation under all possible initial states, it indicates that the model has strong generalisation ability. This means that the model not only performs well under specific training conditions but can also effectively complete tasks in varying environments.

# %%
# Function to calculate the Manhattan distance between two points, used to calculate the optimal steps
def manhattan_distance(point1, point2):
    return abs(point1[0] - point2[0]) + abs(point1[1] - point2[1])

# Function to test the agent in the environment for a certain number of episodes (default 100 random episodes)
def test_agent(agent, env, episodes=100, max_steps=100, step_verbose=True):
    # Save the original epsilon value
    original_epsilon = agent.epsilon
    # Set epsilon to 0 to turn off exploration during testing
    agent.epsilon = 0

    # Initialize metrics to calculate overall performance
    success_count = 0.0
    total_steps = 0.0
    total_reward = 0.0
    total_deviation = 0.0
    total_deviation_rate = 0.0

    # Test the agent for the specified number of episodes
    for episode in range(episodes):
        # Reset the environment for each new episode
        state = env.reset()
        done = False
        episode_steps = 0
        episode_reward = 0

        # Initial positions are extracted from the state vector considering the new structure
        initial_agent_location = state[:2]  # Agent's (y,x) position
        initial_item_location = state[2:4]  # Item's (y,x) position
        drop_off_location = state[4:6]  # Target's (y,x) position

        # Calculate theoretical shortest path or optimal steps
        optimal_steps_to_item = manhattan_distance(initial_agent_location, initial_item_location)
        optimal_steps_to_target = manhattan_distance(initial_item_location, drop_off_location)
        optimal_steps = optimal_steps_to_item + optimal_steps_to_target

        if step_verbose:
            print(f"\n--- Episode {episode + 1} ---")
            print(f"Initial Agent Location: {initial_agent_location}")
            print(f"Initial Item Location (A): {initial_item_location}")
            print(f"Drop-Off Location (B): {drop_off_location}")

        # Agent continues until the task is finished or the step limit is reached
        while not done and episode_steps < max_steps:
            action = agent.get_action(state)  # Agent selects an action (0: north, 1: south, 2: west, 3: east)
            next_state, reward, done = env.step(action)  # Execute the action in the environment
            
            episode_steps += 1
            episode_reward += reward
            state = next_state

            if step_verbose:
                # Translate the action back to readable directions
                action_str = ['north', 'south', 'west', 'east'][action]
                # Print the step details
                print(f"Step {episode_steps}: Action = {action_str}, Reward = {reward}, New State = {next_state}")

        # Calculate the deviation from the optimal steps, total deviation, total steps, and total reward
        deviation = episode_steps - optimal_steps
        deviation_rate = deviation / optimal_steps 
        total_deviation += deviation
        total_deviation_rate += deviation_rate
        total_steps += episode_steps
        total_reward += episode_reward

        # Count the number of successful episodes where the agent delivers the item to the target location
        if done and np.array_equal(state[:2], drop_off_location) and state[-1] == 1:  # Adjusted to check has_item status at the end of the state vector
            success_count += 1

        if step_verbose:
            # Print the summary of the episode
            print(f"Episode {episode + 1} Summary: Steps = {episode_steps} (Optimal Steps = {optimal_steps}), Total Reward = {episode_reward}, Deviation from Optimal: {deviation}")

    # Restore the original epsilon value after testing
    agent.epsilon = original_epsilon

    # Calculate final metrics
    success_rate = success_count / episodes
    average_steps = total_steps / episodes
    average_reward = total_reward / episodes
    average_reward_per_step = total_reward / total_steps / episodes
    average_deviation = total_deviation / episodes
    average_deviation_rate = total_deviation_rate / episodes

    if step_verbose:
        # Print the overall metrics after all test episodes
        print("\n--- Overall Performance Metrics ---")
        print(f'Success Rate: {success_rate * 100:.2f}%')
        print(f'Average Steps to Completion: {average_steps:.2f}')
        print(f'Average Reward: {average_reward:.2f}')
        print(f'Average Reward per Step: {average_reward_per_step:.2f}')
        print(f'Average Deviation from Optimal: {average_deviation:.2f}')
        print(f'Average Deviation Rate: {average_deviation_rate:.2f}%')

    return {
        'success_rate': success_rate * 100,
        'average_steps': average_steps,
        'average_reward': average_reward,
        'average_deviation_rate': average_deviation_rate
    }

# %% [markdown]
# #### **Test 1: Evaluating model performance with different training episodes**
# To evaluate how the number of training episodes affects model performance, we designed and conducted the following experiment:
#
# ##### **Code implementation**
# In this experiment, we set different numbers of training episodes, including 1500, 2500, 3500, 4500 episodes. We then conducted 5 tests for each model and repeated the tests 5 times, calculating the mean and standard deviation of the following metrics:
#
# - **Success Rate**: The success rate indicates the percentage of trials where the agent successfully completes the task, usually expressed as a percentage. It reflects the overall effectiveness of the model.
#
# - **Average Steps**: Average steps represent the number of steps the agent takes to complete the task from the initial position. This metric reflects the efficiency of the agent in executing the task—the fewer steps, the better the path found by the agent.
#
# - **Average Reward**: Average reward represents the total average reward the agent accumulates during the task. This metric reflects the effectiveness of the agent's strategy, with higher rewards indicating more effective behaviour.
#
# - **Average Deviation Rate from Optimal**: This metric represents the average difference between the agent's actual path and the theoretically optimal path, reflecting the optimisation of the agent's strategy. The smaller the deviation, the closer the agent's strategy is to the optimal solution. The calculation formula is given as
#
# \begin{equation*}
# \frac{{\text{actual steps} - \text{optimal steps}}}{{\text{optimal steps}}}.
# \end{equation*}
#
# By plotting these metrics against the number of training episodes, we can visually observe the impact of training episodes on model performance.
#
#
#
# ##### **Explanation**
#
# 1. We chose to start with 1500 episodes because using 10 to 500 episodes often resulted in excessively long test times. Although we could eventually obtain results, the stability of those results could not be guaranteed.
#
# 2. The reason for introducing the "Average Deviation Rate from Optimal" metric is that the other three metrics have their own limitations. The Success Rate does not adequately reflect the intelligence of the agent. Due to varying initial states, both Average Steps and Average Reward can also show inconsistencies. Therefore, we designed the Average Deviation Rate from Optimal metric, expressed as a ratio, to capture the degree of deviation between the agent’s actions and the optimal actions. This metric provides a better reflection of the agent’s intelligence.
#
# 3. In a single epoch, we conducted multiple tests (test_episodes) and repeated the training and testing across multiple epochs (num_repeats). This approach was taken to minimise the impact of random initial states on the results and to more accurately measure how the model’s performance trends with training.
#
# 4. One possible testing method is to use a fixed initial state to compare the metrics corresponding to different training levels (training episodes). However, after careful consideration, we discontinued this approach because it only reflects changes in the model under a single initial state, which differs from our actual requirement for the model (i.e., solving the task independently of the location of A).

# %%
# Set a step limit (e.g., 50 for a 4x4 grid, calculated based on the grid and task complexity)
STEP_LIMIT = 50

training_episodes_list = [100, 200, 300, 400, 500, 750, 1000]
test_episodes = 100
num_repeats = 5  # Use 5 for more robust statistics

# Set up the environment
env = GridWorld(size=4)  # Ensure this matches your GridWorld's setup

# Dictionary to store results
results = {
    'training_episodes': [],
    'success_rate_mean': [],
    'success_rate_std': [],
    'average_steps_mean': [],
    'average_steps_std': [],
    'average_reward_mean': [],
    'average_reward_std': [],
    'average_deviation_rate_mean': [],
    'average_deviation_rate_std': []
}

# Run the experiment for different training episodes
for training_episodes in training_episodes_list:
    print(f"\n--- Training with {training_episodes} Episodes ---")
    success_rates = []
    average_steps = []
    average_rewards = []
    average_deviations = []
    
    # Repeat the experiment for each training episode
    for _ in range(num_repeats):
        print(f"\n--- Repeat {_ + 1} ---")
        # Reinitialize the agent for each training run
        state_size = 11  # Example: (y, x) for agent, item, target, directions to item and target, and has_item
        action_size = 4  # ['north', 'south', 'west', 'east']
        agent = DeepQAgent(state_size=state_size, action_size=action_size)
        
        # Train the agent
        train_agent(agent, env, training_episodes, max_steps=STEP_LIMIT, update_freq=5)
        
        # Test the agent
        metrics = test_agent(agent, env, episodes=test_episodes, max_steps=STEP_LIMIT, step_verbose=False)
        
        # Store individual test results
        success_rates.append(metrics['success_rate'])
        average_steps.append(metrics['average_steps'])
        average_rewards.append(metrics['average_reward'])
        average_deviations.append(metrics['average_deviation_rate'])
    
    # Store mean and standard deviation of results
    results['training_episodes'].append(training_episodes)
    results['success_rate_mean'].append(np.mean(success_rates))
    results['success_rate_std'].append(np.std(success_rates))
    results['average_steps_mean'].append(np.mean(average_steps))
    results['average_steps_std'].append(np.std(average_steps))
    results['average_reward_mean'].append(np.mean(average_rewards))
    results['average_reward_std'].append(np.std(average_rewards))
    results['average_deviation_rate_mean'].append(np.mean(average_deviations))
    results['average_deviation_rate_std'].append(np.std(average_deviations))

# Plotting results with error bars
plt.figure(figsize=(10, 6))
plt.suptitle('Test 1. Model Performance with Different Training Episodes', fontsize=16)

plt.subplot(2, 2, 1)
plt.errorbar(results['training_episodes'], results['success_rate_mean'], 
             yerr=np.array(results['success_rate_std']) * 0.1, fmt='-o', ecolor='red', capsize=5)
plt.title('Success Rate')
plt.xlabel('Training Episodes')
plt.ylabel('Success Rate (%)')

plt.subplot(2, 2, 2)
plt.errorbar(results['training_episodes'], results['average_steps_mean'], 
             yerr=np.array(results['average_steps_std']) * 0.1, fmt='-o', ecolor='red', capsize=5)
plt.title('Average Steps to Completion')
plt.xlabel('Training Episodes')
plt.ylabel('Average Steps')

plt.subplot(2, 2, 3)
plt.errorbar(results['training_episodes'], results['average_reward_mean'], 
             yerr=np.array(results['average_reward_std']) * 0.1, fmt='-o', ecolor='red', capsize=5)
plt.title('Average Reward')
plt.xlabel('Training Episodes')
plt.ylabel('Average Reward')

plt.subplot(2, 2, 4)
plt.errorbar(results['training_episodes'], results['average_deviation_rate_mean'], 
             yerr=np.array(results['average_deviation_rate_std']) * 0.1, fmt='-o', ecolor='red', capsize=5)
plt.title('Average Deviation Rate from Optimal')
plt.xlabel('Training Episodes')
plt.ylabel('Average Deviation')

plt.tight_layout()
plt.show()

print("success_rate_mean:", results['success_rate_mean'])
print("average_steps_mean:", results['average_steps_mean'])
print("average_reward_mean:", results['average_reward_mean'])
print("average_deviation_rate_mean:", results['average_deviation_rate_mean'])
# Out:
# --- Training with 100 Episodes ---
#
# --- Repeat 1 ---
# Episode 100/100 completed (345.90s), epsilon: 0.606
#
# --- Repeat 2 ---
# Episode 100/100 completed (393.19s), epsilon: 0.606
#
# --- Repeat 3 ---
# Episode 100/100 completed (403.66s), epsilon: 0.606
#
# --- Repeat 4 ---
# Episode 100/100 completed (369.27s), epsilon: 0.606
#
# --- Repeat 5 ---
# Episode 100/100 completed (316.49s), epsilon: 0.606
#
# --- Training with 250 Episodes ---
#
# --- Repeat 1 ---
# Episode 100/250 completed (391.64s), epsilon: 0.606
# Episode 200/250 completed (156.30s), epsilon: 0.367
# Episode 250/250 completed (49.42s), epsilon: 0.286
#
# --- Repeat 2 ---
# Episode 100/250 completed (320.71s), epsilon: 0.606
# Episode 200/250 completed (138.32s), epsilon: 0.367
# Episode 250/250 completed (55.44s), epsilon: 0.286
#
# --- Repeat 3 ---
# Episode 100/250 completed (365.96s), epsilon: 0.606
# Episode 200/250 completed (153.28s), epsilon: 0.367
# Episode 250/250 completed (50.55s), epsilon: 0.286
#
# --- Repeat 4 ---
# Episode 100/250 completed (375.42s), epsilon: 0.606
# Episode 200/250 completed (173.02s), epsilon: 0.367
# Episode 250/250 completed (53.24s), epsilon: 0.286
#
# --- Repeat 5 ---
# Episode 100/250 completed (345.68s), epsilon: 0.606
# Episode 200/250 completed (178.47s), epsilon: 0.367
# Episode 250/250 completed (59.11s), epsilon: 0.286
#
# --- Training with 500 Episodes ---
#
# --- Repeat 1 ---
# Episode 100/500 completed (367.37s), epsilon: 0.606
# Episode 200/500 completed (182.36s), epsilon: 0.367
# Episode 300/500 completed (94.36s), epsilon: 0.222
# Episode 400/500 completed (79.53s), epsilon: 0.135
# Episode 500/500 completed (69.62s), epsilon: 0.100
#
# --- Repeat 2 ---
# Episode 100/500 completed (338.66s), epsilon: 0.606
# Episode 200/500 completed (180.62s), epsilon: 0.367
# Episode 300/500 completed (95.34s), epsilon: 0.222
# Episode 400/500 completed (72.06s), epsilon: 0.135
# Episode 500/500 completed (71.47s), epsilon: 0.100
#
# --- Repeat 3 ---
# Episode 100/500 completed (358.95s), epsilon: 0.606
# Episode 200/500 completed (152.27s), epsilon: 0.367
# Episode 300/500 completed (99.30s), epsilon: 0.222
# Episode 400/500 completed (75.42s), epsilon: 0.135
# Episode 500/500 completed (68.54s), epsilon: 0.100
#
# --- Repeat 4 ---
# Episode 100/500 completed (396.50s), epsilon: 0.606
# Episode 200/500 completed (186.68s), epsilon: 0.367
# Episode 300/500 completed (110.37s), epsilon: 0.222
# Episode 400/500 completed (78.35s), epsilon: 0.135
# Episode 500/500 completed (76.87s), epsilon: 0.100
#
# --- Repeat 5 ---
# Episode 100/500 completed (430.82s), epsilon: 0.606
# Episode 200/500 completed (155.96s), epsilon: 0.367
# Episode 300/500 completed (105.29s), epsilon: 0.222
# Episode 400/500 completed (85.57s), epsilon: 0.135
# Episode 500/500 completed (71.82s), epsilon: 0.100
#
# --- Training with 750 Episodes ---
#
# --- Repeat 1 ---
# Episode 100/750 completed (366.16s), epsilon: 0.606
# Episode 200/750 completed (149.11s), epsilon: 0.367
# Episode 300/750 completed (93.40s), epsilon: 0.222
# Episode 400/750 completed (79.59s), epsilon: 0.135
# Episode 500/750 completed (72.66s), epsilon: 0.100
# Episode 600/750 completed (71.77s), epsilon: 0.100
# Episode 700/750 completed (70.72s), epsilon: 0.100
# Episode 750/750 completed (34.62s), epsilon: 0.100
#
# --- Repeat 2 ---
# Episode 100/750 completed (338.34s), epsilon: 0.606
# Episode 200/750 completed (153.04s), epsilon: 0.367
# Episode 300/750 completed (51.97s), epsilon: 0.222
# Episode 400/750 completed (34.57s), epsilon: 0.135
# Episode 500/750 completed (71.69s), epsilon: 0.100
# Episode 600/750 completed (71.63s), epsilon: 0.100
# Episode 700/750 completed (75.05s), epsilon: 0.100
# Episode 750/750 completed (37.66s), epsilon: 0.100
#
# --- Repeat 3 ---
# Episode 100/750 completed (238.43s), epsilon: 0.606
# Episode 200/750 completed (57.90s), epsilon: 0.367
# Episode 300/750 completed (37.26s), epsilon: 0.222
# Episode 400/750 completed (29.75s), epsilon: 0.135
# Episode 500/750 completed (29.81s), epsilon: 0.100
# Episode 600/750 completed (27.09s), epsilon: 0.100
# Episode 700/750 completed (28.70s), epsilon: 0.100
# Episode 750/750 completed (15.59s), epsilon: 0.100
#
# --- Repeat 4 ---
# Episode 100/750 completed (138.80s), epsilon: 0.606
# Episode 200/750 completed (62.67s), epsilon: 0.367
# Episode 300/750 completed (40.30s), epsilon: 0.222
# Episode 400/750 completed (33.34s), epsilon: 0.135
# Episode 500/750 completed (28.59s), epsilon: 0.100
# Episode 600/750 completed (31.41s), epsilon: 0.100
# Episode 700/750 completed (30.01s), epsilon: 0.100
# Episode 750/750 completed (14.30s), epsilon: 0.100
#
# --- Repeat 5 ---
# Episode 100/750 completed (151.36s), epsilon: 0.606
# Episode 200/750 completed (62.44s), epsilon: 0.367
# Episode 300/750 completed (40.55s), epsilon: 0.222
# Episode 400/750 completed (33.77s), epsilon: 0.135
# Episode 500/750 completed (27.39s), epsilon: 0.100
# Episode 600/750 completed (28.82s), epsilon: 0.100
# Episode 700/750 completed (29.25s), epsilon: 0.100
# Episode 750/750 completed (13.41s), epsilon: 0.100
#
# --- Training with 1000 Episodes ---
#
# --- Repeat 1 ---
# Episode 100/1000 completed (149.02s), epsilon: 0.606
# Episode 200/1000 completed (63.13s), epsilon: 0.367
# Episode 300/1000 completed (44.37s), epsilon: 0.222
# Episode 400/1000 completed (37.18s), epsilon: 0.135
# Episode 500/1000 completed (30.22s), epsilon: 0.100
# Episode 600/1000 completed (26.42s), epsilon: 0.100
# Episode 700/1000 completed (25.47s), epsilon: 0.100
# Episode 800/1000 completed (24.82s), epsilon: 0.100
# Episode 900/1000 completed (27.08s), epsilon: 0.100
# Episode 1000/1000 completed (24.36s), epsilon: 0.100
#
# --- Repeat 2 ---
# Episode 100/1000 completed (235.87s), epsilon: 0.606
# Episode 200/1000 completed (169.99s), epsilon: 0.367
# Episode 300/1000 completed (89.29s), epsilon: 0.222
# Episode 400/1000 completed (84.75s), epsilon: 0.135
# Episode 500/1000 completed (26.32s), epsilon: 0.100
# Episode 600/1000 completed (68.69s), epsilon: 0.100
# Episode 700/1000 completed (72.22s), epsilon: 0.100
# Episode 800/1000 completed (64.00s), epsilon: 0.100
# Episode 900/1000 completed (73.20s), epsilon: 0.100
# Episode 1000/1000 completed (72.28s), epsilon: 0.100
#
# --- Repeat 3 ---
# Episode 100/1000 completed (368.83s), epsilon: 0.606
# Episode 200/1000 completed (183.94s), epsilon: 0.367
# Episode 300/1000 completed (106.15s), epsilon: 0.222
# Episode 400/1000 completed (97.62s), epsilon: 0.135
# Episode 500/1000 completed (73.82s), epsilon: 0.100
# Episode 600/1000 completed (68.06s), epsilon: 0.100
# Episode 700/1000 completed (67.69s), epsilon: 0.100
# Episode 800/1000 completed (72.85s), epsilon: 0.100
# Episode 900/1000 completed (67.06s), epsilon: 0.100
# Episode 1000/1000 completed (66.11s), epsilon: 0.100
#
# --- Repeat 4 ---
# Episode 100/1000 completed (343.21s), epsilon: 0.606
# Episode 200/1000 completed (185.17s), epsilon: 0.367
# Episode 300/1000 completed (100.39s), epsilon: 0.222
# Episode 400/1000 completed (80.09s), epsilon: 0.135
# Episode 500/1000 completed (69.28s), epsilon: 0.100
# Episode 600/1000 completed (72.22s), epsilon: 0.100
# Episode 700/1000 completed (65.30s), epsilon: 0.100
# Episode 800/1000 completed (67.65s), epsilon: 0.100
# Episode 900/1000 completed (62.94s), epsilon: 0.100
# Episode 1000/1000 completed (67.90s), epsilon: 0.100
#
# --- Repeat 5 ---
# Episode 100/1000 completed (367.83s), epsilon: 0.606
# Episode 200/1000 completed (162.34s), epsilon: 0.367
# Episode 300/1000 completed (102.70s), epsilon: 0.222
# Episode 400/1000 completed (90.04s), epsilon: 0.135
# Episode 500/1000 completed (77.18s), epsilon: 0.100
# Episode 600/1000 completed (69.51s), epsilon: 0.100
# Episode 700/1000 completed (66.23s), epsilon: 0.100
# Episode 800/1000 completed (71.43s), epsilon: 0.100
# Episode 900/1000 completed (76.12s), epsilon: 0.100
# Episode 1000/1000 completed (68.00s), epsilon: 0.100
# success_rate_mean: [59.8, 95.2, 98.8, 100.0, 99.8]
# average_steps_mean: [23.142, 7.5120000000000005, 5.944, 5.244, 5.468]
# average_reward_mean: [20.568, 87.45599999999999, 93.10799999999999, 95.756, 95.33]
# average_deviation_rate_mean: [3.629559163059163, 0.5100857142857143, 0.07482900432900433, 0.0, 0.018]

# %% [markdown]
# Based on the test results, we can observe that as the number of training episodes increases, the model's Average Steps and Average Deviation Rate from Optimal consistently decrease, while the Average Reward steadily increases. This clearly demonstrates that the capability of the agent we designed improves with more training and approaches optimal performance. It can be seen that after approximately 3000 training episodes, the model's performance is already very close to optimal performance.

# %% [markdown]
# ### **Test 2: Evaluating the performance of a model trained extensively across all initial states**
# In the second test, we selected a model trained with 50000 episodes and evaluated its performance across all possible initial states. Specifically, we traversed all possible combinations of the agent's initial position and the item's position, measuring the model's performance in these scenarios.
#
# #### **Code implementation**
# To cover all possible initial states, we traversed each possible agent starting position and item position in a 5x5 grid and conducted multiple tests for each state. We recorded the success rate, average steps, average reward, and deviation rate from the optimal strategy, and the corresponding means and standard deviations are provided. It is worth pointing out that we exclude cases where the initial item position is the same as the initial agent position, and the initial item position is the same as the target location according to the assumptions.
#
# #### **Capability assessment**
# The purpose of this test is to evaluate whether the model, after extensive training, can perform well across all initial states. This is crucial for assessing the model's generalisation ability: whether it can successfully complete the task and achieve high rewards regardless of the initial conditions.

# %%
# Training parameters
training_episodes = 5000  # Number of training episodes
test_episodes = 100  # Number of test episodes per configuration
num_repeats = 5  # Number of repeats per initial configuration

# Grid size
grid_size = 4

# Initialize the environment
env = GridWorld(size=grid_size)

# Initialize the Deep Q-learning agent
# State size now includes agent, item, target (y,x), directions (to item and target), and possession status
state_size = 11  # 2 for agent (y,x), 2 for item (y,x), 2 for target (y,x), 4 for directions, 1 for possession status
action_size = 4  # Four possible actions (north, south, west, east)
agent = DeepQAgent(state_size=state_size, action_size=action_size)

# Train the agent
train_agent(agent, env, training_episodes)

# Initialize dictionaries to store results
results = {
    'initial_states': [],
    'success_rate_mean': [],
    'success_rate_std': [],
    'average_steps_mean': [],
    'average_steps_std': [],
    'average_reward_mean': [],
    'average_reward_std': [],
    'average_deviation_rate_mean': [],
    'average_deviation_rate_std': []
}

# Iterate over all possible initial states (agent start position, item position and target position)
for start_x in range(grid_size):
	for start_y in range(grid_size):
		for item_x in range(grid_size):
			for item_y in range(grid_size):
				for target_x in range(grid_size):
					for target_y in range(grid_size):
						success_rates = []
						average_steps = []
						average_rewards = []
						average_deviations = []

						initial_agent_pos = (start_x, start_y)
						initial_item_pos = (item_x, item_y)
						initial_target_pos = (target_x, target_y)
						if  initial_item_pos == initial_agent_pos:
							continue
						if initial_item_pos == initial_target_pos:
							continue

            			# Repeat the test multiple times for each initial state
						for _ in range(num_repeats):
							# Reinitialise the environment with the given agent and item positions
							# preset_agent_location=(4, 0), preset_item_location=(0, 4), preset_target_location=(4,4)
							env = GridWorld(size=grid_size, preset_agent_location=initial_agent_pos, preset_item_location=initial_item_pos, preset_target_location=initial_target_pos, given_location=True)
							metrics = test_agent(agent, env, episodes=test_episodes, step_verbose=False)

							# Store individual test results
							success_rates.append(metrics['success_rate'])
							average_steps.append(metrics['average_steps'])
							average_rewards.append(metrics['average_reward'])
							average_deviations.append(metrics['average_deviation_rate'])

							# Store the mean and standard deviation of results
							results['success_rate_mean'].append(np.mean(success_rates))
							results['success_rate_std'].append(np.std(success_rates))
							results['average_steps_mean'].append(np.mean(average_steps))
							results['average_steps_std'].append(np.std(average_steps))
							results['average_reward_mean'].append(np.mean(average_rewards))
							results['average_reward_std'].append(np.std(average_rewards))
							results['average_deviation_rate_mean'].append(np.mean(average_deviations))
							results['average_deviation_rate_std'].append(np.std(average_deviations))

# Print final summary
print(f"\n--- Final Summary over {num_repeats} Repeats of {test_episodes} Test Episodes ---")
print(f"success_rate: {np.mean(results['success_rate_mean']).round(2)} +/- {np.mean(results['success_rate_std']).round(2)}")
print(f"average_steps: {np.mean(results['average_steps_mean']).round(2)} +/- {np.mean(results['average_steps_std']).round(2)}")
print(f"average_reward: {np.mean(results['average_reward_mean']).round(2)} +/- {np.mean(results['average_reward_std']).round(2)}")
print(f"average_deviation_rate: {np.mean(results['average_deviation_rate_mean']).round(2)} +/- {np.mean(results['average_deviation_rate_std']).round(2)}")
# Out:
# Episode 1/1 completed (0.00s), epsilon: 0.995
#
# --- Initial Configuration 1 ---
#
# --- Initial Configuration 2 ---
#
# --- Initial Configuration 3 ---
#
# --- Initial Configuration 4 ---
#
# --- Initial Configuration 5 ---
#
# --- Initial Configuration 6 ---
#
# --- Initial Configuration 7 ---
#
# --- Initial Configuration 8 ---
#
# --- Initial Configuration 9 ---
#
# --- Initial Configuration 10 ---
#
# --- Initial Configuration 11 ---
#
# --- Initial Configuration 12 ---
#
# --- Initial Configuration 13 ---
#
# --- Initial Configuration 14 ---
#
# --- Initial Configuration 15 ---
#
# --- Initial Configuration 16 ---
#
# --- Initial Configuration 17 ---
#
# --- Initial Configuration 18 ---
#
# --- Initial Configuration 19 ---
#
# --- Initial Configuration 20 ---
#
# --- Initial Configuration 21 ---
#
# --- Initial Configuration 22 ---
#
# --- Initial Configuration 23 ---
#
# --- Initial Configuration 24 ---
#
# --- Initial Configuration 25 ---
#
# --- Initial Configuration 26 ---
#
# --- Initial Configuration 27 ---
#
# --- Initial Configuration 28 ---
#
# --- Initial Configuration 29 ---
#
# --- Initial Configuration 30 ---
#
# --- Initial Configuration 31 ---
#
# --- Initial Configuration 32 ---
#
# --- Initial Configuration 33 ---
#
# --- Initial Configuration 34 ---
#
# --- Initial Configuration 35 ---
#
# --- Initial Configuration 36 ---
#
# --- Initial Configuration 37 ---
#
# --- Initial Configuration 38 ---
#
# --- Initial Configuration 39 ---
#
# --- Initial Configuration 40 ---
#
# --- Initial Configuration 41 ---
#
# --- Initial Configuration 42 ---
#
# --- Initial Configuration 43 ---
#
# --- Initial Configuration 44 ---
#
# --- Initial Configuration 45 ---
#
# --- Initial Configuration 46 ---
#
# --- Initial Configuration 47 ---
#
# --- Initial Configuration 48 ---
#
# --- Initial Configuration 49 ---
#
# --- Initial Configuration 50 ---
#
# --- Initial Configuration 51 ---
#
# --- Initial Configuration 52 ---
#
# --- Initial Configuration 53 ---
#
# --- Initial Configuration 54 ---
#
# --- Initial Configuration 55 ---
#
# --- Initial Configuration 56 ---
#
# --- Initial Configuration 57 ---
#
# --- Initial Configuration 58 ---
#
# --- Initial Configuration 59 ---
#
# --- Initial Configuration 60 ---
#
# --- Initial Configuration 61 ---
#
# --- Initial Configuration 62 ---
#
# --- Initial Configuration 63 ---
#
# --- Initial Configuration 64 ---
#
# --- Initial Configuration 65 ---
#
# --- Initial Configuration 66 ---
#
# --- Initial Configuration 67 ---
#
# --- Initial Configuration 68 ---
#
# --- Initial Configuration 69 ---
#
# --- Initial Configuration 70 ---
#
# --- Initial Configuration 71 ---
#
# --- Initial Configuration 72 ---
#
# --- Initial Configuration 73 ---
#
# --- Initial Configuration 74 ---
#
# --- Initial Configuration 75 ---
#
# --- Initial Configuration 76 ---
#
# --- Initial Configuration 77 ---
#
# --- Initial Configuration 78 ---
#
# --- Initial Configuration 79 ---
#
# --- Initial Configuration 80 ---
#
# --- Initial Configuration 81 ---
#
# --- Initial Configuration 82 ---
#
# --- Initial Configuration 83 ---
#
# --- Initial Configuration 84 ---
#
# --- Initial Configuration 85 ---
#
# --- Initial Configuration 86 ---
#
# --- Initial Configuration 87 ---
#
# --- Initial Configuration 88 ---
#
# --- Initial Configuration 89 ---
#
# --- Initial Configuration 90 ---
#
# --- Initial Configuration 91 ---
#
# --- Initial Configuration 92 ---
#
# --- Initial Configuration 93 ---
#
# --- Initial Configuration 94 ---
#
# --- Initial Configuration 95 ---
#
# --- Initial Configuration 96 ---
#
# --- Initial Configuration 97 ---
#
# --- Initial Configuration 98 ---
#
# --- Initial Configuration 99 ---
#
# --- Initial Configuration 100 ---
#
# --- Initial Configuration 101 ---
#
# --- Initial Configuration 102 ---
#
# --- Initial Configuration 103 ---
#
# --- Initial Configuration 104 ---
#
# --- Initial Configuration 105 ---
#
# --- Initial Configuration 106 ---
#
# --- Initial Configuration 107 ---
#
# --- Initial Configuration 108 ---
#
# --- Initial Configuration 109 ---
#
# --- Initial Configuration 110 ---
#
# --- Initial Configuration 111 ---
#
# --- Initial Configuration 112 ---
#
# --- Initial Configuration 113 ---
#
# --- Initial Configuration 114 ---
#
# --- Initial Configuration 115 ---
#
# --- Initial Configuration 116 ---
#
# --- Initial Configuration 117 ---
#
# --- Initial Configuration 118 ---
#
# --- Initial Configuration 119 ---
#
# --- Initial Configuration 120 ---
#
# --- Initial Configuration 121 ---
#
# --- Initial Configuration 122 ---
#
# --- Initial Configuration 123 ---
#
# --- Initial Configuration 124 ---
#
# --- Initial Configuration 125 ---
#
# --- Initial Configuration 126 ---
#
# --- Initial Configuration 127 ---
#
# --- Initial Configuration 128 ---
#
# --- Initial Configuration 129 ---
#
# --- Initial Configuration 130 ---
#
# --- Initial Configuration 131 ---
#
# --- Initial Configuration 132 ---
#
# --- Initial Configuration 133 ---
#
# --- Initial Configuration 134 ---
#
# --- Initial Configuration 135 ---
#
# --- Initial Configuration 136 ---
#
# --- Initial Configuration 137 ---
#
# --- Initial Configuration 138 ---
#
# --- Initial Configuration 139 ---
#
# --- Initial Configuration 140 ---
#
# --- Initial Configuration 141 ---
#
# --- Initial Configuration 142 ---
#
# --- Initial Configuration 143 ---
#
# --- Initial Configuration 144 ---
#
# --- Initial Configuration 145 ---
#
# --- Initial Configuration 146 ---
#
# --- Initial Configuration 147 ---
#
# --- Initial Configuration 148 ---
#
# --- Initial Configuration 149 ---
#
# --- Initial Configuration 150 ---
#
# --- Initial Configuration 151 ---
#
# --- Initial Configuration 152 ---
#
# --- Initial Configuration 153 ---
#
# --- Initial Configuration 154 ---
#
# --- Initial Configuration 155 ---
#
# --- Initial Configuration 156 ---
#
# --- Initial Configuration 157 ---
#
# --- Initial Configuration 158 ---
#
# --- Initial Configuration 159 ---
#
# --- Initial Configuration 160 ---
#
# --- Initial Configuration 161 ---
#
# --- Initial Configuration 162 ---
#
# --- Initial Configuration 163 ---
#
# --- Initial Configuration 164 ---
#
# --- Initial Configuration 165 ---
#
# --- Initial Configuration 166 ---
#
# --- Initial Configuration 167 ---
#
# --- Initial Configuration 168 ---
#
# --- Initial Configuration 169 ---
#
# --- Initial Configuration 170 ---
#
# --- Initial Configuration 171 ---
#
# --- Initial Configuration 172 ---
#
# --- Initial Configuration 173 ---
#
# --- Initial Configuration 174 ---
#
# --- Initial Configuration 175 ---
#
# --- Initial Configuration 176 ---
#
# --- Initial Configuration 177 ---
#
# --- Initial Configuration 178 ---
#
# --- Initial Configuration 179 ---
#
# --- Initial Configuration 180 ---
#
# --- Initial Configuration 181 ---
#
# --- Initial Configuration 182 ---
#
# --- Initial Configuration 183 ---
#
# --- Initial Configuration 184 ---
#
# --- Initial Configuration 185 ---
#
# --- Initial Configuration 186 ---
#
# --- Initial Configuration 187 ---
#
# --- Initial Configuration 188 ---
#
# --- Initial Configuration 189 ---
#
# --- Initial Configuration 190 ---
#
# --- Initial Configuration 191 ---
#
# --- Initial Configuration 192 ---
#
# --- Initial Configuration 193 ---
#
# --- Initial Configuration 194 ---
#
# --- Initial Configuration 195 ---
#
# --- Initial Configuration 196 ---
#
# --- Initial Configuration 197 ---
#
# --- Initial Configuration 198 ---
#
# --- Initial Configuration 199 ---
#
# --- Initial Configuration 200 ---
#
# --- Initial Configuration 201 ---
#
# --- Initial Configuration 202 ---
#
# --- Initial Configuration 203 ---
#
# --- Initial Configuration 204 ---
#
# --- Initial Configuration 205 ---
#
# --- Initial Configuration 206 ---
#
# --- Initial Configuration 207 ---
#
# --- Initial Configuration 208 ---
#
# --- Initial Configuration 209 ---
#
# --- Initial Configuration 210 ---
#
# --- Initial Configuration 211 ---
#
# --- Initial Configuration 212 ---
#
# --- Initial Configuration 213 ---
#
# --- Initial Configuration 214 ---
#
# --- Initial Configuration 215 ---
#
# --- Initial Configuration 216 ---
#
# --- Initial Configuration 217 ---
#
# --- Initial Configuration 218 ---
#
# --- Initial Configuration 219 ---
#
# --- Initial Configuration 220 ---
#
# --- Initial Configuration 221 ---
#
# --- Initial Configuration 222 ---
#
# --- Initial Configuration 223 ---
#
# --- Initial Configuration 224 ---
#
# --- Initial Configuration 225 ---
#
# --- Initial Configuration 226 ---
#
# --- Initial Configuration 227 ---
#
# --- Initial Configuration 228 ---
#
# --- Initial Configuration 229 ---
#
# --- Initial Configuration 230 ---
#
# --- Initial Configuration 231 ---
#
# --- Initial Configuration 232 ---
#
# --- Initial Configuration 233 ---
#
# --- Initial Configuration 234 ---
#
# --- Initial Configuration 235 ---
#
# --- Initial Configuration 236 ---
#
# --- Initial Configuration 237 ---
#
# --- Initial Configuration 238 ---
#
# --- Initial Configuration 239 ---
#
# --- Initial Configuration 240 ---
#
# --- Initial Configuration 241 ---
#
# --- Initial Configuration 242 ---
#
# --- Initial Configuration 243 ---
#
# --- Initial Configuration 244 ---
#
# --- Initial Configuration 245 ---
#
# --- Initial Configuration 246 ---
#
# --- Initial Configuration 247 ---
#
# --- Initial Configuration 248 ---
#
# --- Initial Configuration 249 ---
#
# --- Initial Configuration 250 ---
#
# --- Initial Configuration 251 ---
#
# --- Initial Configuration 252 ---
#
# --- Initial Configuration 253 ---
#
# --- Initial Configuration 254 ---
#
# --- Initial Configuration 255 ---
#
# --- Initial Configuration 256 ---
#
# --- Initial Configuration 257 ---
#
# --- Initial Configuration 258 ---
#
# --- Initial Configuration 259 ---
#
# --- Initial Configuration 260 ---
#
# --- Initial Configuration 261 ---
#
# --- Initial Configuration 262 ---
#
# --- Initial Configuration 263 ---
#
# --- Initial Configuration 264 ---
#
# --- Initial Configuration 265 ---
#
# --- Initial Configuration 266 ---
#
# --- Initial Configuration 267 ---
#
# --- Initial Configuration 268 ---
#
# --- Initial Configuration 269 ---
#
# --- Initial Configuration 270 ---
#
# --- Initial Configuration 271 ---
#
# --- Initial Configuration 272 ---
#
# --- Initial Configuration 273 ---
#
# --- Initial Configuration 274 ---
#
# --- Initial Configuration 275 ---
#
# --- Initial Configuration 276 ---
#
# --- Initial Configuration 277 ---
#
# --- Initial Configuration 278 ---
#
# --- Initial Configuration 279 ---
#
# --- Initial Configuration 280 ---
#
# --- Initial Configuration 281 ---
#
# --- Initial Configuration 282 ---
#
# --- Initial Configuration 283 ---
#
# --- Initial Configuration 284 ---
#
# --- Initial Configuration 285 ---
#
# --- Initial Configuration 286 ---
#
# --- Initial Configuration 287 ---
#
# --- Initial Configuration 288 ---
#
# --- Initial Configuration 289 ---
#
# --- Initial Configuration 290 ---
#
# --- Initial Configuration 291 ---
#
# --- Initial Configuration 292 ---
#
# --- Initial Configuration 293 ---
#
# --- Initial Configuration 294 ---
#
# --- Initial Configuration 295 ---
#
# --- Initial Configuration 296 ---
#
# --- Initial Configuration 297 ---
#
# --- Initial Configuration 298 ---
#
# --- Initial Configuration 299 ---
#
# --- Initial Configuration 300 ---
#
# --- Initial Configuration 301 ---
#
# --- Initial Configuration 302 ---
#
# --- Initial Configuration 303 ---
#
# --- Initial Configuration 304 ---
#
# --- Initial Configuration 305 ---
#
# --- Initial Configuration 306 ---
#
# --- Initial Configuration 307 ---
#
# --- Initial Configuration 308 ---
#
# --- Initial Configuration 309 ---
#
# --- Initial Configuration 310 ---
#
# --- Initial Configuration 311 ---
#
# --- Initial Configuration 312 ---
#
# --- Initial Configuration 313 ---
#
# --- Initial Configuration 314 ---
#
# --- Initial Configuration 315 ---
#
# --- Initial Configuration 316 ---
#
# --- Initial Configuration 317 ---
#
# --- Initial Configuration 318 ---
#
# --- Initial Configuration 319 ---
#
# --- Initial Configuration 320 ---
#
# --- Initial Configuration 321 ---
#
# --- Initial Configuration 322 ---
#
# --- Initial Configuration 323 ---
#
# --- Initial Configuration 324 ---
#
# --- Initial Configuration 325 ---
#
# --- Initial Configuration 326 ---
#
# --- Initial Configuration 327 ---
#
# --- Initial Configuration 328 ---
#
# --- Initial Configuration 329 ---
#
# --- Initial Configuration 330 ---
#
# --- Initial Configuration 331 ---
#
# --- Initial Configuration 332 ---
#
# --- Initial Configuration 333 ---
#
# --- Initial Configuration 334 ---
#
# --- Initial Configuration 335 ---
#
# --- Initial Configuration 336 ---
#
# --- Initial Configuration 337 ---
#
# --- Initial Configuration 338 ---
#
# --- Initial Configuration 339 ---
#
# --- Initial Configuration 340 ---
#
# --- Initial Configuration 341 ---
#
# --- Initial Configuration 342 ---
#
# --- Initial Configuration 343 ---
#
# --- Initial Configuration 344 ---
#
# --- Initial Configuration 345 ---
#
# --- Initial Configuration 346 ---
#
# --- Initial Configuration 347 ---
#
# --- Initial Configuration 348 ---
#
# --- Initial Configuration 349 ---
#
# --- Initial Configuration 350 ---
#
# --- Initial Configuration 351 ---
#
# --- Initial Configuration 352 ---
#
# --- Initial Configuration 353 ---
#
# --- Initial Configuration 354 ---
#
# --- Initial Configuration 355 ---
#
# --- Initial Configuration 356 ---
#
# --- Initial Configuration 357 ---
#
# --- Initial Configuration 358 ---
#
# --- Initial Configuration 359 ---
#
# --- Initial Configuration 360 ---
#
# --- Initial Configuration 361 ---
#
# --- Initial Configuration 362 ---
#
# --- Initial Configuration 363 ---
#
# --- Initial Configuration 364 ---
#
# --- Initial Configuration 365 ---
#
# --- Initial Configuration 366 ---
#
# --- Initial Configuration 367 ---
#
# --- Initial Configuration 368 ---
#
# --- Initial Configuration 369 ---
#
# --- Initial Configuration 370 ---
#
# --- Initial Configuration 371 ---
#
# --- Initial Configuration 372 ---
#
# --- Initial Configuration 373 ---
#
# --- Initial Configuration 374 ---
#
# --- Initial Configuration 375 ---
#
# --- Initial Configuration 376 ---
#
# --- Initial Configuration 377 ---
#
# --- Initial Configuration 378 ---
#
# --- Initial Configuration 379 ---
#
# --- Initial Configuration 380 ---
#
# --- Initial Configuration 381 ---
#
# --- Initial Configuration 382 ---
#
# --- Initial Configuration 383 ---
#
# --- Initial Configuration 384 ---
#
# --- Initial Configuration 385 ---
#
# --- Initial Configuration 386 ---
#
# --- Initial Configuration 387 ---
#
# --- Initial Configuration 388 ---
#
# --- Initial Configuration 389 ---
#
# --- Initial Configuration 390 ---
#
# --- Initial Configuration 391 ---
#
# --- Initial Configuration 392 ---
#
# --- Initial Configuration 393 ---
#
# --- Initial Configuration 394 ---
#
# --- Initial Configuration 395 ---
#
# --- Initial Configuration 396 ---
#
# --- Initial Configuration 397 ---
#
# --- Initial Configuration 398 ---
#
# --- Initial Configuration 399 ---
#
# --- Initial Configuration 400 ---
#
# --- Initial Configuration 401 ---
#
# --- Initial Configuration 402 ---
#
# --- Initial Configuration 403 ---
#
# --- Initial Configuration 404 ---
#
# --- Initial Configuration 405 ---
#
# --- Initial Configuration 406 ---
#
# --- Initial Configuration 407 ---
#
# --- Initial Configuration 408 ---
#
# --- Initial Configuration 409 ---
#
# --- Initial Configuration 410 ---
#
# --- Initial Configuration 411 ---
#
# --- Initial Configuration 412 ---
#
# --- Initial Configuration 413 ---
#
# --- Initial Configuration 414 ---
#
# --- Initial Configuration 415 ---
#
# --- Initial Configuration 416 ---
#
# --- Initial Configuration 417 ---
#
# --- Initial Configuration 418 ---
#
# --- Initial Configuration 419 ---
#
# --- Initial Configuration 420 ---
#
# --- Initial Configuration 421 ---
#
# --- Initial Configuration 422 ---
#
# --- Initial Configuration 423 ---
#
# --- Initial Configuration 424 ---
#
# --- Initial Configuration 425 ---
#
# --- Initial Configuration 426 ---
#
# --- Initial Configuration 427 ---
#
# --- Initial Configuration 428 ---
#
# --- Initial Configuration 429 ---
#
# --- Initial Configuration 430 ---
#
# --- Initial Configuration 431 ---
#
# --- Initial Configuration 432 ---
#
# --- Initial Configuration 433 ---
#
# --- Initial Configuration 434 ---
#
# --- Initial Configuration 435 ---
#
# --- Initial Configuration 436 ---
#
# --- Initial Configuration 437 ---
#
# --- Initial Configuration 438 ---
#
# --- Initial Configuration 439 ---
#
# --- Initial Configuration 440 ---
#
# --- Initial Configuration 441 ---
#
# --- Initial Configuration 442 ---
#
# --- Initial Configuration 443 ---
#
# --- Initial Configuration 444 ---
#
# --- Initial Configuration 445 ---
#
# --- Initial Configuration 446 ---
#
# --- Initial Configuration 447 ---
#
# --- Initial Configuration 448 ---
#
# --- Initial Configuration 449 ---
#
# --- Initial Configuration 450 ---
#
# --- Initial Configuration 451 ---
#
# --- Initial Configuration 452 ---
#
# --- Initial Configuration 453 ---
#
# --- Initial Configuration 454 ---
#
# --- Initial Configuration 455 ---
#
# --- Initial Configuration 456 ---
#
# --- Initial Configuration 457 ---
#
# --- Initial Configuration 458 ---
#
# --- Initial Configuration 459 ---
#
# --- Initial Configuration 460 ---
#
# --- Initial Configuration 461 ---
#
# --- Initial Configuration 462 ---
#
# --- Initial Configuration 463 ---
#
# --- Initial Configuration 464 ---
#
# --- Initial Configuration 465 ---
#
# --- Initial Configuration 466 ---
#
# --- Initial Configuration 467 ---
#
# --- Initial Configuration 468 ---
#
# --- Initial Configuration 469 ---
#
# --- Initial Configuration 470 ---
#
# --- Initial Configuration 471 ---
#
# --- Initial Configuration 472 ---
#
# --- Initial Configuration 473 ---
#
# --- Initial Configuration 474 ---
#
# --- Initial Configuration 475 ---
#
# --- Initial Configuration 476 ---
#
# --- Initial Configuration 477 ---
#
# --- Initial Configuration 478 ---
#
# --- Initial Configuration 479 ---
#
# --- Initial Configuration 480 ---
#
# --- Initial Configuration 481 ---
#
# --- Initial Configuration 482 ---
#
# --- Initial Configuration 483 ---
#
# --- Initial Configuration 484 ---
#
# --- Initial Configuration 485 ---
#
# --- Initial Configuration 486 ---
#
# --- Initial Configuration 487 ---
#
# --- Initial Configuration 488 ---
#
# --- Initial Configuration 489 ---
#
# --- Initial Configuration 490 ---
#
# --- Initial Configuration 491 ---
#
# --- Initial Configuration 492 ---
#
# --- Initial Configuration 493 ---
#
# --- Initial Configuration 494 ---
#
# --- Initial Configuration 495 ---
#
# --- Initial Configuration 496 ---
#
# --- Initial Configuration 497 ---
#
# --- Initial Configuration 498 ---
#
# --- Initial Configuration 499 ---
#
# --- Initial Configuration 500 ---
#
# --- Initial Configuration 501 ---
#
# --- Initial Configuration 502 ---
#
# --- Initial Configuration 503 ---
#
# --- Initial Configuration 504 ---
#
# --- Initial Configuration 505 ---
#
# --- Initial Configuration 506 ---
#
# --- Initial Configuration 507 ---
#
# --- Initial Configuration 508 ---
#
# --- Initial Configuration 509 ---
#
# --- Initial Configuration 510 ---
#
# --- Initial Configuration 511 ---
#
# --- Initial Configuration 512 ---
#
# --- Initial Configuration 513 ---
#
# --- Initial Configuration 514 ---
#
# --- Initial Configuration 515 ---
#
# --- Initial Configuration 516 ---
#
# --- Initial Configuration 517 ---
#
# --- Initial Configuration 518 ---
#
# --- Initial Configuration 519 ---
#
# --- Initial Configuration 520 ---
#
# --- Initial Configuration 521 ---
#
# --- Initial Configuration 522 ---
#
# --- Initial Configuration 523 ---
#
# --- Initial Configuration 524 ---
#
# --- Initial Configuration 525 ---
#
# --- Initial Configuration 526 ---
#
# --- Initial Configuration 527 ---
#
# --- Initial Configuration 528 ---
#
# --- Initial Configuration 529 ---
#
# --- Initial Configuration 530 ---
#
# --- Initial Configuration 531 ---
#
# --- Initial Configuration 532 ---
#
# --- Initial Configuration 533 ---
#
# --- Initial Configuration 534 ---
#
# --- Initial Configuration 535 ---
#
# --- Initial Configuration 536 ---
#
# --- Initial Configuration 537 ---
#
# --- Initial Configuration 538 ---
#
# --- Initial Configuration 539 ---
#
# --- Initial Configuration 540 ---
#
# --- Initial Configuration 541 ---
#
# --- Initial Configuration 542 ---
#
# --- Initial Configuration 543 ---
#
# --- Initial Configuration 544 ---
#
# --- Initial Configuration 545 ---
#
# --- Initial Configuration 546 ---
#
# --- Initial Configuration 547 ---
#
# --- Initial Configuration 548 ---
#
# --- Initial Configuration 549 ---
#
# --- Initial Configuration 550 ---
#
# --- Initial Configuration 551 ---
#
# --- Initial Configuration 552 ---
#
# --- Initial Configuration 553 ---
#
# --- Initial Configuration 554 ---
#
# --- Initial Configuration 555 ---
#
# --- Initial Configuration 556 ---
#
# --- Initial Configuration 557 ---
#
# --- Initial Configuration 558 ---
#
# --- Initial Configuration 559 ---
#
# --- Initial Configuration 560 ---
#
# --- Initial Configuration 561 ---
#
# --- Initial Configuration 562 ---
#
# --- Initial Configuration 563 ---
#
# --- Initial Configuration 564 ---
#
# --- Initial Configuration 565 ---
#
# --- Initial Configuration 566 ---
#
# --- Initial Configuration 567 ---
#
# --- Initial Configuration 568 ---
#
# --- Initial Configuration 569 ---
#
# --- Initial Configuration 570 ---
#
# --- Initial Configuration 571 ---
#
# --- Initial Configuration 572 ---
#
# --- Initial Configuration 573 ---
#
# --- Initial Configuration 574 ---
#
# --- Initial Configuration 575 ---
#
# --- Initial Configuration 576 ---
#
# --- Initial Configuration 577 ---
#
# --- Initial Configuration 578 ---
#
# --- Initial Configuration 579 ---
#
# --- Initial Configuration 580 ---
#
# --- Initial Configuration 581 ---
#
# --- Initial Configuration 582 ---
#
# --- Initial Configuration 583 ---
#
# --- Initial Configuration 584 ---
#
# --- Initial Configuration 585 ---
#
# --- Initial Configuration 586 ---
#
# --- Initial Configuration 587 ---
#
# --- Initial Configuration 588 ---
#
# --- Initial Configuration 589 ---
#
# --- Initial Configuration 590 ---
#
# --- Initial Configuration 591 ---
#
# --- Initial Configuration 592 ---
#
# --- Initial Configuration 593 ---
#
# --- Initial Configuration 594 ---
#
# --- Initial Configuration 595 ---
#
# --- Initial Configuration 596 ---
#
# --- Initial Configuration 597 ---
#
# --- Initial Configuration 598 ---
#
# --- Initial Configuration 599 ---
#
# --- Initial Configuration 600 ---
#
# --- Initial Configuration 601 ---
#
# --- Initial Configuration 602 ---
#
# --- Initial Configuration 603 ---
#
# --- Initial Configuration 604 ---
#
# --- Initial Configuration 605 ---
#
# --- Initial Configuration 606 ---
#
# --- Initial Configuration 607 ---
#
# --- Initial Configuration 608 ---
#
# --- Initial Configuration 609 ---
#
# --- Initial Configuration 610 ---
#
# --- Initial Configuration 611 ---
#
# --- Initial Configuration 612 ---
#
# --- Initial Configuration 613 ---
#
# --- Initial Configuration 614 ---
#
# --- Initial Configuration 615 ---
#
# --- Initial Configuration 616 ---
#
# --- Initial Configuration 617 ---
#
# --- Initial Configuration 618 ---
#
# --- Initial Configuration 619 ---
#
# --- Initial Configuration 620 ---
#
# --- Initial Configuration 621 ---
#
# --- Initial Configuration 622 ---
#
# --- Initial Configuration 623 ---
#
# --- Initial Configuration 624 ---
#
# --- Initial Configuration 625 ---
#
# --- Initial Configuration 626 ---
#
# --- Initial Configuration 627 ---
#
# --- Initial Configuration 628 ---
#
# --- Initial Configuration 629 ---
#
# --- Initial Configuration 630 ---
#
# --- Initial Configuration 631 ---
#
# --- Initial Configuration 632 ---
#
# --- Initial Configuration 633 ---
#
# --- Initial Configuration 634 ---
#
# --- Initial Configuration 635 ---
#
# --- Initial Configuration 636 ---
#
# --- Initial Configuration 637 ---
#
# --- Initial Configuration 638 ---
#
# --- Initial Configuration 639 ---
#
# --- Initial Configuration 640 ---
#
# --- Initial Configuration 641 ---
#
# --- Initial Configuration 642 ---
#
# --- Initial Configuration 643 ---
#
# --- Initial Configuration 644 ---
#
# --- Initial Configuration 645 ---
#
# --- Initial Configuration 646 ---
#
# --- Initial Configuration 647 ---
#
# --- Initial Configuration 648 ---
#
# --- Initial Configuration 649 ---
#
# --- Initial Configuration 650 ---
#
# --- Initial Configuration 651 ---
#
# --- Initial Configuration 652 ---
#
# --- Initial Configuration 653 ---
#
# --- Initial Configuration 654 ---
#
# --- Initial Configuration 655 ---
#
# --- Initial Configuration 656 ---
#
# --- Initial Configuration 657 ---
#
# --- Initial Configuration 658 ---
#
# --- Initial Configuration 659 ---
#
# --- Initial Configuration 660 ---
#
# --- Initial Configuration 661 ---
#
# --- Initial Configuration 662 ---
#
# --- Initial Configuration 663 ---
#
# --- Initial Configuration 664 ---
#
# --- Initial Configuration 665 ---
#
# --- Initial Configuration 666 ---
#
# --- Initial Configuration 667 ---
#
# --- Initial Configuration 668 ---
#
# --- Initial Configuration 669 ---
#
# --- Initial Configuration 670 ---
#
# --- Initial Configuration 671 ---
#
# --- Initial Configuration 672 ---
#
# --- Initial Configuration 673 ---
#
# --- Initial Configuration 674 ---
#
# --- Initial Configuration 675 ---
#
# --- Initial Configuration 676 ---
#
# --- Initial Configuration 677 ---
#
# --- Initial Configuration 678 ---
#
# --- Initial Configuration 679 ---
#
# --- Initial Configuration 680 ---
#
# --- Initial Configuration 681 ---
#
# --- Initial Configuration 682 ---
#
# --- Initial Configuration 683 ---
#
# --- Initial Configuration 684 ---
#
# --- Initial Configuration 685 ---
#
# --- Initial Configuration 686 ---
#
# --- Initial Configuration 687 ---
#
# --- Initial Configuration 688 ---
#
# --- Initial Configuration 689 ---
#
# --- Initial Configuration 690 ---
#
# --- Initial Configuration 691 ---
#
# --- Initial Configuration 692 ---
#
# --- Initial Configuration 693 ---
#
# --- Initial Configuration 694 ---
#
# --- Initial Configuration 695 ---
#
# --- Initial Configuration 696 ---
#
# --- Initial Configuration 697 ---
#
# --- Initial Configuration 698 ---
#
# --- Initial Configuration 699 ---
#
# --- Initial Configuration 700 ---
#
# --- Initial Configuration 701 ---
#
# --- Initial Configuration 702 ---
#
# --- Initial Configuration 703 ---
#
# --- Initial Configuration 704 ---
#
# --- Initial Configuration 705 ---
#
# --- Initial Configuration 706 ---
#
# --- Initial Configuration 707 ---
#
# --- Initial Configuration 708 ---
#
# --- Initial Configuration 709 ---
#
# --- Initial Configuration 710 ---
#
# --- Initial Configuration 711 ---
#
# --- Initial Configuration 712 ---
#
# --- Initial Configuration 713 ---
#
# --- Initial Configuration 714 ---
#
# --- Initial Configuration 715 ---
#
# --- Initial Configuration 716 ---
#
# --- Initial Configuration 717 ---
#
# --- Initial Configuration 718 ---
#
# --- Initial Configuration 719 ---
#
# --- Initial Configuration 720 ---
#
# --- Initial Configuration 721 ---
#
# --- Initial Configuration 722 ---
#
# --- Initial Configuration 723 ---
#
# --- Initial Configuration 724 ---
#
# --- Initial Configuration 725 ---
#
# --- Initial Configuration 726 ---
#
# --- Initial Configuration 727 ---
#
# --- Initial Configuration 728 ---
#
# --- Initial Configuration 729 ---
#
# --- Initial Configuration 730 ---
#
# --- Initial Configuration 731 ---
#
# --- Initial Configuration 732 ---
#
# --- Initial Configuration 733 ---
#
# --- Initial Configuration 734 ---
#
# --- Initial Configuration 735 ---
#
# --- Initial Configuration 736 ---
#
# --- Initial Configuration 737 ---
#
# --- Initial Configuration 738 ---
#
# --- Initial Configuration 739 ---
#
# --- Initial Configuration 740 ---
#
# --- Initial Configuration 741 ---
#
# --- Initial Configuration 742 ---
#
# --- Initial Configuration 743 ---
#
# --- Initial Configuration 744 ---
#
# --- Initial Configuration 745 ---
#
# --- Initial Configuration 746 ---
#
# --- Initial Configuration 747 ---
#
# --- Initial Configuration 748 ---
#
# --- Initial Configuration 749 ---
#
# --- Initial Configuration 750 ---
#
# --- Initial Configuration 751 ---
#
# --- Initial Configuration 752 ---
#
# --- Initial Configuration 753 ---
#
# --- Initial Configuration 754 ---
#
# --- Initial Configuration 755 ---
#
# --- Initial Configuration 756 ---
#
# --- Initial Configuration 757 ---
#
# --- Initial Configuration 758 ---
#
# --- Initial Configuration 759 ---
#
# --- Initial Configuration 760 ---
#
# --- Initial Configuration 761 ---
#
# --- Initial Configuration 762 ---
#
# --- Initial Configuration 763 ---
#
# --- Initial Configuration 764 ---
#
# --- Initial Configuration 765 ---
#
# --- Initial Configuration 766 ---
#
# --- Initial Configuration 767 ---
#
# --- Initial Configuration 768 ---
#
# --- Initial Configuration 769 ---
#
# --- Initial Configuration 770 ---
#
# --- Initial Configuration 771 ---
#
# --- Initial Configuration 772 ---
#
# --- Initial Configuration 773 ---
#
# --- Initial Configuration 774 ---
#
# --- Initial Configuration 775 ---
#
# --- Initial Configuration 776 ---
#
# --- Initial Configuration 777 ---
#
# --- Initial Configuration 778 ---
#
# --- Initial Configuration 779 ---
#
# --- Initial Configuration 780 ---
#
# --- Initial Configuration 781 ---
#
# --- Initial Configuration 782 ---
#
# --- Initial Configuration 783 ---
#
# --- Initial Configuration 784 ---
#
# --- Initial Configuration 785 ---
#
# --- Initial Configuration 786 ---
#
# --- Initial Configuration 787 ---
#
# --- Initial Configuration 788 ---
#
# --- Initial Configuration 789 ---
#
# --- Initial Configuration 790 ---
#
# --- Initial Configuration 791 ---
#
# --- Initial Configuration 792 ---
#
# --- Initial Configuration 793 ---
#
# --- Initial Configuration 794 ---
#
# --- Initial Configuration 795 ---
#
# --- Initial Configuration 796 ---
#
# --- Initial Configuration 797 ---
#
# --- Initial Configuration 798 ---
#
# --- Initial Configuration 799 ---
#
# --- Initial Configuration 800 ---
#
# --- Initial Configuration 801 ---
#
# --- Initial Configuration 802 ---
#
# --- Initial Configuration 803 ---
#
# --- Initial Configuration 804 ---
#
# --- Initial Configuration 805 ---
#
# --- Initial Configuration 806 ---
#
# --- Initial Configuration 807 ---
#
# --- Initial Configuration 808 ---
#
# --- Initial Configuration 809 ---
#
# --- Initial Configuration 810 ---
#
# --- Initial Configuration 811 ---
#
# --- Initial Configuration 812 ---
#
# --- Initial Configuration 813 ---
#
# --- Initial Configuration 814 ---
#
# --- Initial Configuration 815 ---
#
# --- Initial Configuration 816 ---
#
# --- Initial Configuration 817 ---
#
# --- Initial Configuration 818 ---
#
# --- Initial Configuration 819 ---
#
# --- Initial Configuration 820 ---
#
# --- Initial Configuration 821 ---
#
# --- Initial Configuration 822 ---
#
# --- Initial Configuration 823 ---
#
# --- Initial Configuration 824 ---
#
# --- Initial Configuration 825 ---
#
# --- Initial Configuration 826 ---
#
# --- Initial Configuration 827 ---
#
# --- Initial Configuration 828 ---
#
# --- Initial Configuration 829 ---
#
# --- Initial Configuration 830 ---
#
# --- Initial Configuration 831 ---
#
# --- Initial Configuration 832 ---
#
# --- Initial Configuration 833 ---
#
# --- Initial Configuration 834 ---
#
# --- Initial Configuration 835 ---
#
# --- Initial Configuration 836 ---
#
# --- Initial Configuration 837 ---
#
# --- Initial Configuration 838 ---
#
# --- Initial Configuration 839 ---
#
# --- Initial Configuration 840 ---
#
# --- Initial Configuration 841 ---
#
# --- Initial Configuration 842 ---
#
# --- Initial Configuration 843 ---
#
# --- Initial Configuration 844 ---
#
# --- Initial Configuration 845 ---
#
# --- Initial Configuration 846 ---
#
# --- Initial Configuration 847 ---
#
# --- Initial Configuration 848 ---
#
# --- Initial Configuration 849 ---
#
# --- Initial Configuration 850 ---
#
# --- Initial Configuration 851 ---
#
# --- Initial Configuration 852 ---
#
# --- Initial Configuration 853 ---
#
# --- Initial Configuration 854 ---
#
# --- Initial Configuration 855 ---
#
# --- Initial Configuration 856 ---
#
# --- Initial Configuration 857 ---
#
# --- Initial Configuration 858 ---
#
# --- Initial Configuration 859 ---
#
# --- Initial Configuration 860 ---
#
# --- Initial Configuration 861 ---
#
# --- Initial Configuration 862 ---
#
# --- Initial Configuration 863 ---
#
# --- Initial Configuration 864 ---
#
# --- Initial Configuration 865 ---
#
# --- Initial Configuration 866 ---
#
# --- Initial Configuration 867 ---
#
# --- Initial Configuration 868 ---
#
# --- Initial Configuration 869 ---
#
# --- Initial Configuration 870 ---
#
# --- Initial Configuration 871 ---
#
# --- Initial Configuration 872 ---
#
# --- Initial Configuration 873 ---
#
# --- Initial Configuration 874 ---
#
# --- Initial Configuration 875 ---
#
# --- Initial Configuration 876 ---
#
# --- Initial Configuration 877 ---
#
# --- Initial Configuration 878 ---
#
# --- Initial Configuration 879 ---
#
# --- Initial Configuration 880 ---
#
# --- Initial Configuration 881 ---
#
# --- Initial Configuration 882 ---
#
# --- Initial Configuration 883 ---
#
# --- Initial Configuration 884 ---
#
# --- Initial Configuration 885 ---
#
# --- Initial Configuration 886 ---
#
# --- Initial Configuration 887 ---
#
# --- Initial Configuration 888 ---
#
# --- Initial Configuration 889 ---
#
# --- Initial Configuration 890 ---
#
# --- Initial Configuration 891 ---
#
# --- Initial Configuration 892 ---
#
# --- Initial Configuration 893 ---
#
# --- Initial Configuration 894 ---
#
# --- Initial Configuration 895 ---
#
# --- Initial Configuration 896 ---
#
# --- Initial Configuration 897 ---
#
# --- Initial Configuration 898 ---
#
# --- Initial Configuration 899 ---
#
# --- Initial Configuration 900 ---
#
# --- Initial Configuration 901 ---
#
# --- Initial Configuration 902 ---
#
# --- Initial Configuration 903 ---
#
# --- Initial Configuration 904 ---
#
# --- Initial Configuration 905 ---
#
# --- Initial Configuration 906 ---
#
# --- Initial Configuration 907 ---
#
# --- Initial Configuration 908 ---
#
# --- Initial Configuration 909 ---
#
# --- Initial Configuration 910 ---
#
# --- Initial Configuration 911 ---
#
# --- Initial Configuration 912 ---
#
# --- Initial Configuration 913 ---
#
# --- Initial Configuration 914 ---
#
# --- Initial Configuration 915 ---
#
# --- Initial Configuration 916 ---
#
# --- Initial Configuration 917 ---
#
# --- Initial Configuration 918 ---
#
# --- Initial Configuration 919 ---
#
# --- Initial Configuration 920 ---
#
# --- Initial Configuration 921 ---
#
# --- Initial Configuration 922 ---
#
# --- Initial Configuration 923 ---
#
# --- Initial Configuration 924 ---
#
# --- Initial Configuration 925 ---
#
# --- Initial Configuration 926 ---
#
# --- Initial Configuration 927 ---
#
# --- Initial Configuration 928 ---
#
# --- Initial Configuration 929 ---
#
# --- Initial Configuration 930 ---
#
# --- Initial Configuration 931 ---
#
# --- Initial Configuration 932 ---
#
# --- Initial Configuration 933 ---
#
# --- Initial Configuration 934 ---
#
# --- Initial Configuration 935 ---
#
# --- Initial Configuration 936 ---
#
# --- Initial Configuration 937 ---
#
# --- Initial Configuration 938 ---
#
# --- Initial Configuration 939 ---
#
# --- Initial Configuration 940 ---
#
# --- Initial Configuration 941 ---
#
# --- Initial Configuration 942 ---
#
# --- Initial Configuration 943 ---
#
# --- Initial Configuration 944 ---
#
# --- Initial Configuration 945 ---
#
# --- Initial Configuration 946 ---
#
# --- Initial Configuration 947 ---
#
# --- Initial Configuration 948 ---
#
# --- Initial Configuration 949 ---
#
# --- Initial Configuration 950 ---
#
# --- Initial Configuration 951 ---
#
# --- Initial Configuration 952 ---
#
# --- Initial Configuration 953 ---
#
# --- Initial Configuration 954 ---
#
# --- Initial Configuration 955 ---
#
# --- Initial Configuration 956 ---
#
# --- Initial Configuration 957 ---
#
# --- Initial Configuration 958 ---
#
# --- Initial Configuration 959 ---
#
# --- Initial Configuration 960 ---
#
# --- Initial Configuration 961 ---
#
# --- Initial Configuration 962 ---
#
# --- Initial Configuration 963 ---
#
# --- Initial Configuration 964 ---
#
# --- Initial Configuration 965 ---
#
# --- Initial Configuration 966 ---
#
# --- Initial Configuration 967 ---
#
# --- Initial Configuration 968 ---
#
# --- Initial Configuration 969 ---
#
# --- Initial Configuration 970 ---
#
# --- Initial Configuration 971 ---
#
# --- Initial Configuration 972 ---
#
# --- Initial Configuration 973 ---
#
# --- Initial Configuration 974 ---
#
# --- Initial Configuration 975 ---
#
# --- Initial Configuration 976 ---
#
# --- Initial Configuration 977 ---
#
# --- Initial Configuration 978 ---
#
# --- Initial Configuration 979 ---
#
# --- Initial Configuration 980 ---
#
# --- Initial Configuration 981 ---
#
# --- Initial Configuration 982 ---
#
# --- Initial Configuration 983 ---
#
# --- Initial Configuration 984 ---
#
# --- Initial Configuration 985 ---
#
# --- Initial Configuration 986 ---
#
# --- Initial Configuration 987 ---
#
# --- Initial Configuration 988 ---
#
# --- Initial Configuration 989 ---
#
# --- Initial Configuration 990 ---
#
# --- Initial Configuration 991 ---
#
# --- Initial Configuration 992 ---
#
# --- Initial Configuration 993 ---
#
# --- Initial Configuration 994 ---
#
# --- Initial Configuration 995 ---
#
# --- Initial Configuration 996 ---
#
# --- Initial Configuration 997 ---
#
# --- Initial Configuration 998 ---
#
# --- Initial Configuration 999 ---
#
# --- Initial Configuration 1000 ---
#
# --- Initial Configuration 1001 ---
#
# --- Initial Configuration 1002 ---
#
# --- Initial Configuration 1003 ---
#
# --- Initial Configuration 1004 ---
#
# --- Initial Configuration 1005 ---
#
# --- Initial Configuration 1006 ---
#
# --- Initial Configuration 1007 ---
#
# --- Initial Configuration 1008 ---
#
# --- Initial Configuration 1009 ---
#
# --- Initial Configuration 1010 ---
#
# --- Initial Configuration 1011 ---
#
# --- Initial Configuration 1012 ---
#
# --- Initial Configuration 1013 ---
#
# --- Initial Configuration 1014 ---
#
# --- Initial Configuration 1015 ---
#
# --- Initial Configuration 1016 ---
#
# --- Initial Configuration 1017 ---
#
# --- Initial Configuration 1018 ---
#
# --- Initial Configuration 1019 ---
#
# --- Initial Configuration 1020 ---
#
# --- Initial Configuration 1021 ---
#
# --- Initial Configuration 1022 ---
#
# --- Initial Configuration 1023 ---
#
# --- Initial Configuration 1024 ---
#
# --- Initial Configuration 1025 ---
#
# --- Initial Configuration 1026 ---
#
# --- Initial Configuration 1027 ---
#
# --- Initial Configuration 1028 ---
#
# --- Initial Configuration 1029 ---
#
# --- Initial Configuration 1030 ---
#
# --- Initial Configuration 1031 ---
#
# --- Initial Configuration 1032 ---
#
# --- Initial Configuration 1033 ---
#
# --- Initial Configuration 1034 ---
#
# --- Initial Configuration 1035 ---
#
# --- Initial Configuration 1036 ---
#
# --- Initial Configuration 1037 ---
#
# --- Initial Configuration 1038 ---
#
# --- Initial Configuration 1039 ---
#
# --- Initial Configuration 1040 ---
#
# --- Initial Configuration 1041 ---
#
# --- Initial Configuration 1042 ---
#
# --- Initial Configuration 1043 ---
#
# --- Initial Configuration 1044 ---
#
# --- Initial Configuration 1045 ---
#
# --- Initial Configuration 1046 ---
#
# --- Initial Configuration 1047 ---
#
# --- Initial Configuration 1048 ---
#
# --- Initial Configuration 1049 ---
#
# --- Initial Configuration 1050 ---
#
# --- Initial Configuration 1051 ---
#
# --- Initial Configuration 1052 ---
#
# --- Initial Configuration 1053 ---
#
# --- Initial Configuration 1054 ---
#
# --- Initial Configuration 1055 ---
#
# --- Initial Configuration 1056 ---
#
# --- Initial Configuration 1057 ---
#
# --- Initial Configuration 1058 ---
#
# --- Initial Configuration 1059 ---
#
# --- Initial Configuration 1060 ---
#
# --- Initial Configuration 1061 ---
#
# --- Initial Configuration 1062 ---
#
# --- Initial Configuration 1063 ---
#
# --- Initial Configuration 1064 ---
#
# --- Initial Configuration 1065 ---
#
# --- Initial Configuration 1066 ---
#
# --- Initial Configuration 1067 ---
#
# --- Initial Configuration 1068 ---
#
# --- Initial Configuration 1069 ---
#
# --- Initial Configuration 1070 ---
#
# --- Initial Configuration 1071 ---
#
# --- Initial Configuration 1072 ---
#
# --- Initial Configuration 1073 ---
#
# --- Initial Configuration 1074 ---
#
# --- Initial Configuration 1075 ---
#
# --- Initial Configuration 1076 ---
#
# --- Initial Configuration 1077 ---
#
# --- Initial Configuration 1078 ---
#
# --- Initial Configuration 1079 ---
#
# --- Initial Configuration 1080 ---
#
# --- Initial Configuration 1081 ---
#
# --- Initial Configuration 1082 ---
#
# --- Initial Configuration 1083 ---
#
# --- Initial Configuration 1084 ---
#
# --- Initial Configuration 1085 ---
#
# --- Initial Configuration 1086 ---
#
# --- Initial Configuration 1087 ---
#
# --- Initial Configuration 1088 ---
#
# --- Initial Configuration 1089 ---
#
# --- Initial Configuration 1090 ---
#
# --- Initial Configuration 1091 ---
#
# --- Initial Configuration 1092 ---
#
# --- Initial Configuration 1093 ---
#
# --- Initial Configuration 1094 ---
#
# --- Initial Configuration 1095 ---
#
# --- Initial Configuration 1096 ---
#
# --- Initial Configuration 1097 ---
#
# --- Initial Configuration 1098 ---
#
# --- Initial Configuration 1099 ---
#
# --- Initial Configuration 1100 ---
#
# --- Initial Configuration 1101 ---
#
# --- Initial Configuration 1102 ---
#
# --- Initial Configuration 1103 ---
#
# --- Initial Configuration 1104 ---
#
# --- Initial Configuration 1105 ---
#
# --- Initial Configuration 1106 ---
#
# --- Initial Configuration 1107 ---
#
# --- Initial Configuration 1108 ---
#
# --- Initial Configuration 1109 ---
#
# --- Initial Configuration 1110 ---
#
# --- Initial Configuration 1111 ---
#
# --- Initial Configuration 1112 ---
#
# --- Initial Configuration 1113 ---
#
# --- Initial Configuration 1114 ---
#
# --- Initial Configuration 1115 ---
#
# --- Initial Configuration 1116 ---
#
# --- Initial Configuration 1117 ---
#
# --- Initial Configuration 1118 ---
#
# --- Initial Configuration 1119 ---
#
# --- Initial Configuration 1120 ---
#
# --- Initial Configuration 1121 ---
#
# --- Initial Configuration 1122 ---
#
# --- Initial Configuration 1123 ---
#
# --- Initial Configuration 1124 ---
#
# --- Initial Configuration 1125 ---
#
# --- Initial Configuration 1126 ---
#
# --- Initial Configuration 1127 ---
#
# --- Initial Configuration 1128 ---
#
# --- Initial Configuration 1129 ---
#
# --- Initial Configuration 1130 ---
#
# --- Initial Configuration 1131 ---
#
# --- Initial Configuration 1132 ---
#
# --- Initial Configuration 1133 ---
#
# --- Initial Configuration 1134 ---
#
# --- Initial Configuration 1135 ---
#
# --- Initial Configuration 1136 ---
#
# --- Initial Configuration 1137 ---
#
# --- Initial Configuration 1138 ---
#
# --- Initial Configuration 1139 ---
#
# --- Initial Configuration 1140 ---
#
# --- Initial Configuration 1141 ---
#
# --- Initial Configuration 1142 ---
#
# --- Initial Configuration 1143 ---
#
# --- Initial Configuration 1144 ---
#
# --- Initial Configuration 1145 ---
#
# --- Initial Configuration 1146 ---
#
# --- Initial Configuration 1147 ---
#
# --- Initial Configuration 1148 ---
#
# --- Initial Configuration 1149 ---
#
# --- Initial Configuration 1150 ---
#
# --- Initial Configuration 1151 ---
#
# --- Initial Configuration 1152 ---
#
# --- Initial Configuration 1153 ---
#
# --- Initial Configuration 1154 ---
#
# --- Initial Configuration 1155 ---
#
# --- Initial Configuration 1156 ---
#
# --- Initial Configuration 1157 ---
#
# --- Initial Configuration 1158 ---
#
# --- Initial Configuration 1159 ---
#
# --- Initial Configuration 1160 ---
#
# --- Initial Configuration 1161 ---
#
# --- Initial Configuration 1162 ---
#
# --- Initial Configuration 1163 ---
#
# --- Initial Configuration 1164 ---
#
# --- Initial Configuration 1165 ---
#
# --- Initial Configuration 1166 ---
#
# --- Initial Configuration 1167 ---
#
# --- Initial Configuration 1168 ---
#
# --- Initial Configuration 1169 ---
#
# --- Initial Configuration 1170 ---
#
# --- Initial Configuration 1171 ---
#
# --- Initial Configuration 1172 ---
#
# --- Initial Configuration 1173 ---
#
# --- Initial Configuration 1174 ---
#
# --- Initial Configuration 1175 ---
#
# --- Initial Configuration 1176 ---
#
# --- Initial Configuration 1177 ---
#
# --- Initial Configuration 1178 ---
#
# --- Initial Configuration 1179 ---
#
# --- Initial Configuration 1180 ---
#
# --- Initial Configuration 1181 ---
#
# --- Initial Configuration 1182 ---
#
# --- Initial Configuration 1183 ---
#
# --- Initial Configuration 1184 ---
#
# --- Initial Configuration 1185 ---
#
# --- Initial Configuration 1186 ---
#
# --- Initial Configuration 1187 ---
#
# --- Initial Configuration 1188 ---
#
# --- Initial Configuration 1189 ---
#
# --- Initial Configuration 1190 ---
#
# --- Initial Configuration 1191 ---
#
# --- Initial Configuration 1192 ---
#
# --- Initial Configuration 1193 ---
#
# --- Initial Configuration 1194 ---
#
# --- Initial Configuration 1195 ---
#
# --- Initial Configuration 1196 ---
#
# --- Initial Configuration 1197 ---
#
# --- Initial Configuration 1198 ---
#
# --- Initial Configuration 1199 ---
#
# --- Initial Configuration 1200 ---
#
# --- Initial Configuration 1201 ---
#
# --- Initial Configuration 1202 ---
#
# --- Initial Configuration 1203 ---
#
# --- Initial Configuration 1204 ---
#
# --- Initial Configuration 1205 ---
#
# --- Initial Configuration 1206 ---
#
# --- Initial Configuration 1207 ---
#
# --- Initial Configuration 1208 ---
#
# --- Initial Configuration 1209 ---
#
# --- Initial Configuration 1210 ---
#
# --- Initial Configuration 1211 ---
#
# --- Initial Configuration 1212 ---
#
# --- Initial Configuration 1213 ---
#
# --- Initial Configuration 1214 ---
#
# --- Initial Configuration 1215 ---
#
# --- Initial Configuration 1216 ---
#
# --- Initial Configuration 1217 ---
#
# --- Initial Configuration 1218 ---
#
# --- Initial Configuration 1219 ---
#
# --- Initial Configuration 1220 ---
#
# --- Initial Configuration 1221 ---
#
# --- Initial Configuration 1222 ---
#
# --- Initial Configuration 1223 ---
#
# --- Initial Configuration 1224 ---
#
# --- Initial Configuration 1225 ---
#
# --- Initial Configuration 1226 ---
#
# --- Initial Configuration 1227 ---
#
# --- Initial Configuration 1228 ---
#
# --- Initial Configuration 1229 ---
#
# --- Initial Configuration 1230 ---
#
# --- Initial Configuration 1231 ---
#
# --- Initial Configuration 1232 ---
#
# --- Initial Configuration 1233 ---
#
# --- Initial Configuration 1234 ---
#
# --- Initial Configuration 1235 ---
#
# --- Initial Configuration 1236 ---
#
# --- Initial Configuration 1237 ---
#
# --- Initial Configuration 1238 ---
#
# --- Initial Configuration 1239 ---
#
# --- Initial Configuration 1240 ---
#
# --- Initial Configuration 1241 ---
#
# --- Initial Configuration 1242 ---
#
# --- Initial Configuration 1243 ---
#
# --- Initial Configuration 1244 ---
#
# --- Initial Configuration 1245 ---
#
# --- Initial Configuration 1246 ---
#
# --- Initial Configuration 1247 ---
#
# --- Initial Configuration 1248 ---
#
# --- Initial Configuration 1249 ---
#
# --- Initial Configuration 1250 ---
#
# --- Initial Configuration 1251 ---
#
# --- Initial Configuration 1252 ---
#
# --- Initial Configuration 1253 ---
#
# --- Initial Configuration 1254 ---
#
# --- Initial Configuration 1255 ---
#
# --- Initial Configuration 1256 ---
#
# --- Initial Configuration 1257 ---
#
# --- Initial Configuration 1258 ---
#
# --- Initial Configuration 1259 ---
#
# --- Initial Configuration 1260 ---
#
# --- Initial Configuration 1261 ---
#
# --- Initial Configuration 1262 ---
#
# --- Initial Configuration 1263 ---
#
# --- Initial Configuration 1264 ---
#
# --- Initial Configuration 1265 ---
#
# --- Initial Configuration 1266 ---
#
# --- Initial Configuration 1267 ---
#
# --- Initial Configuration 1268 ---
#
# --- Initial Configuration 1269 ---
#
# --- Initial Configuration 1270 ---
#
# --- Initial Configuration 1271 ---
#
# --- Initial Configuration 1272 ---
#
# --- Initial Configuration 1273 ---
#
# --- Initial Configuration 1274 ---
#
# --- Initial Configuration 1275 ---
#
# --- Initial Configuration 1276 ---
#
# --- Initial Configuration 1277 ---
#
# --- Initial Configuration 1278 ---
#
# --- Initial Configuration 1279 ---
#
# --- Initial Configuration 1280 ---
#
# --- Initial Configuration 1281 ---
#
# --- Initial Configuration 1282 ---
#
# --- Initial Configuration 1283 ---
#
# --- Initial Configuration 1284 ---
#
# --- Initial Configuration 1285 ---
#
# --- Initial Configuration 1286 ---
#
# --- Initial Configuration 1287 ---
#
# --- Initial Configuration 1288 ---
#
# --- Initial Configuration 1289 ---
#
# --- Initial Configuration 1290 ---
#
# --- Initial Configuration 1291 ---
#
# --- Initial Configuration 1292 ---
#
# --- Initial Configuration 1293 ---
#
# --- Initial Configuration 1294 ---
#
# --- Initial Configuration 1295 ---
#
# --- Initial Configuration 1296 ---
#
# --- Initial Configuration 1297 ---
#
# --- Initial Configuration 1298 ---
#
# --- Initial Configuration 1299 ---
#
# --- Initial Configuration 1300 ---
#
# --- Initial Configuration 1301 ---
#
# --- Initial Configuration 1302 ---
#
# --- Initial Configuration 1303 ---
#
# --- Initial Configuration 1304 ---
#
# --- Initial Configuration 1305 ---
#
# --- Initial Configuration 1306 ---
#
# --- Initial Configuration 1307 ---
#
# --- Initial Configuration 1308 ---
#
# --- Initial Configuration 1309 ---
#
# --- Initial Configuration 1310 ---
#
# --- Initial Configuration 1311 ---
#
# --- Initial Configuration 1312 ---
#
# --- Initial Configuration 1313 ---
#
# --- Initial Configuration 1314 ---
#
# --- Initial Configuration 1315 ---
#
# --- Initial Configuration 1316 ---
#
# --- Initial Configuration 1317 ---
#
# --- Initial Configuration 1318 ---
#
# --- Initial Configuration 1319 ---
#
# --- Initial Configuration 1320 ---
#
# --- Initial Configuration 1321 ---
#
# --- Initial Configuration 1322 ---
#
# --- Initial Configuration 1323 ---
#
# --- Initial Configuration 1324 ---
#
# --- Initial Configuration 1325 ---
#
# --- Initial Configuration 1326 ---
#
# --- Initial Configuration 1327 ---
#
# --- Initial Configuration 1328 ---
#
# --- Initial Configuration 1329 ---
#
# --- Initial Configuration 1330 ---
#
# --- Initial Configuration 1331 ---
#
# --- Initial Configuration 1332 ---
#
# --- Initial Configuration 1333 ---
#
# --- Initial Configuration 1334 ---
#
# --- Initial Configuration 1335 ---
#
# --- Initial Configuration 1336 ---
#
# --- Initial Configuration 1337 ---
#
# --- Initial Configuration 1338 ---
#
# --- Initial Configuration 1339 ---
#
# --- Initial Configuration 1340 ---
#
# --- Initial Configuration 1341 ---
#
# --- Initial Configuration 1342 ---
#
# --- Initial Configuration 1343 ---
#
# --- Initial Configuration 1344 ---
#
# --- Initial Configuration 1345 ---
#
# --- Initial Configuration 1346 ---
#
# --- Initial Configuration 1347 ---
#
# --- Initial Configuration 1348 ---
#
# --- Initial Configuration 1349 ---
#
# --- Initial Configuration 1350 ---
#
# --- Initial Configuration 1351 ---
#
# --- Initial Configuration 1352 ---
#
# --- Initial Configuration 1353 ---
#
# --- Initial Configuration 1354 ---
#
# --- Initial Configuration 1355 ---
#
# --- Initial Configuration 1356 ---
#
# --- Initial Configuration 1357 ---
#
# --- Initial Configuration 1358 ---
#
# --- Initial Configuration 1359 ---
#
# --- Initial Configuration 1360 ---
#
# --- Initial Configuration 1361 ---
#
# --- Initial Configuration 1362 ---
#
# ...
#
# --- Initial Configuration 3658 ---
#
# --- Initial Configuration 3659 ---
#
# --- Initial Configuration 3660 ---
#
# --- Initial Configuration 3661 ---
#
# --- Initial Configuration 3662 ---
#
# --- Initial Configuration 3663 ---
#
# --- Initial Configuration 3664 ---
#
# --- Initial Configuration 3665 ---
#
# --- Initial Configuration 3666 ---
#
# --- Initial Configuration 3667 ---
#
# --- Initial Configuration 3668 ---
#
# --- Initial Configuration 3669 ---
#
# --- Initial Configuration 3670 ---
#
# --- Initial Configuration 3671 ---
#
# --- Initial Configuration 3672 ---
#
# --- Initial Configuration 3673 ---
#
# --- Initial Configuration 3674 ---
#
# --- Initial Configuration 3675 ---
#
# --- Initial Configuration 3676 ---
#
# --- Initial Configuration 3677 ---
#
# --- Initial Configuration 3678 ---
#
# --- Initial Configuration 3679 ---
#
# --- Initial Configuration 3680 ---
#
# --- Initial Configuration 3681 ---
#
# --- Initial Configuration 3682 ---
#
# --- Initial Configuration 3683 ---
#
# --- Initial Configuration 3684 ---
#
# --- Initial Configuration 3685 ---
#
# --- Initial Configuration 3686 ---
#
# --- Initial Configuration 3687 ---
#
# --- Initial Configuration 3688 ---
#
# --- Initial Configuration 3689 ---
#
# --- Initial Configuration 3690 ---
#
# --- Initial Configuration 3691 ---
#
# --- Initial Configuration 3692 ---
#
# --- Initial Configuration 3693 ---
#
# --- Initial Configuration 3694 ---
#
# --- Initial Configuration 3695 ---
#
# --- Initial Configuration 3696 ---
#
# --- Initial Configuration 3697 ---
#
# --- Initial Configuration 3698 ---
#
# --- Initial Configuration 3699 ---
#
# --- Initial Configuration 3700 ---
#
# --- Initial Configuration 3701 ---
#
# --- Initial Configuration 3702 ---
#
# --- Initial Configuration 3703 ---
#
# --- Initial Configuration 3704 ---
#
# --- Initial Configuration 3705 ---
#
# --- Initial Configuration 3706 ---
#
# --- Initial Configuration 3707 ---
#
# --- Initial Configuration 3708 ---
#
# --- Initial Configuration 3709 ---
#
# --- Initial Configuration 3710 ---
#
# --- Initial Configuration 3711 ---
#
# --- Initial Configuration 3712 ---
#
# --- Initial Configuration 3713 ---
#
# --- Initial Configuration 3714 ---
#
# --- Initial Configuration 3715 ---
#
# --- Initial Configuration 3716 ---
#
# --- Initial Configuration 3717 ---
#
# --- Initial Configuration 3718 ---
#
# --- Initial Configuration 3719 ---
#
# --- Initial Configuration 3720 ---
#
# --- Initial Configuration 3721 ---
#
# --- Initial Configuration 3722 ---
#
# --- Initial Configuration 3723 ---
#
# --- Initial Configuration 3724 ---
#
# --- Initial Configuration 3725 ---
#
# --- Initial Configuration 3726 ---
#
# --- Initial Configuration 3727 ---
#
# --- Initial Configuration 3728 ---
#
# --- Initial Configuration 3729 ---
#
# --- Initial Configuration 3730 ---
#
# --- Initial Configuration 3731 ---
#
# --- Initial Configuration 3732 ---
#
# --- Initial Configuration 3733 ---
#
# --- Initial Configuration 3734 ---
#
# --- Initial Configuration 3735 ---
#
# --- Initial Configuration 3736 ---
#
# --- Initial Configuration 3737 ---
#
# --- Initial Configuration 3738 ---
#
# --- Initial Configuration 3739 ---
#
# --- Initial Configuration 3740 ---
#
# --- Initial Configuration 3741 ---
#
# --- Initial Configuration 3742 ---
#
# --- Initial Configuration 3743 ---
#
# --- Initial Configuration 3744 ---
#
# --- Initial Configuration 3745 ---
#
# --- Initial Configuration 3746 ---
#
# --- Initial Configuration 3747 ---
#
# --- Initial Configuration 3748 ---
#
# --- Initial Configuration 3749 ---
#
# --- Initial Configuration 3750 ---
#
# --- Initial Configuration 3751 ---
#
# --- Initial Configuration 3752 ---
#
# --- Initial Configuration 3753 ---
#
# --- Initial Configuration 3754 ---
#
# --- Initial Configuration 3755 ---
#
# --- Initial Configuration 3756 ---
#
# --- Initial Configuration 3757 ---
#
# --- Initial Configuration 3758 ---
#
# --- Initial Configuration 3759 ---
#
# --- Initial Configuration 3760 ---
#
# --- Initial Configuration 3761 ---
#
# --- Initial Configuration 3762 ---
#
# --- Initial Configuration 3763 ---
#
# --- Initial Configuration 3764 ---
#
# --- Initial Configuration 3765 ---
#
# --- Initial Configuration 3766 ---
#
# --- Initial Configuration 3767 ---
#
# --- Initial Configuration 3768 ---
#
# --- Initial Configuration 3769 ---
#
# --- Initial Configuration 3770 ---
#
# --- Initial Configuration 3771 ---
#
# --- Initial Configuration 3772 ---
#
# --- Initial Configuration 3773 ---
#
# --- Initial Configuration 3774 ---
#
# --- Initial Configuration 3775 ---
#
# --- Initial Configuration 3776 ---
#
# --- Initial Configuration 3777 ---
#
# --- Initial Configuration 3778 ---
#
# --- Initial Configuration 3779 ---
#
# --- Initial Configuration 3780 ---
#
# --- Initial Configuration 3781 ---
#
# --- Initial Configuration 3782 ---
#
# --- Initial Configuration 3783 ---
#
# --- Initial Configuration 3784 ---
#
# --- Initial Configuration 3785 ---
#
# --- Initial Configuration 3786 ---
#
# --- Initial Configuration 3787 ---
#
# --- Initial Configuration 3788 ---
#
# --- Initial Configuration 3789 ---
#
# --- Initial Configuration 3790 ---
#
# --- Initial Configuration 3791 ---
#
# --- Initial Configuration 3792 ---
#
# --- Initial Configuration 3793 ---
#
# --- Initial Configuration 3794 ---
#
# --- Initial Configuration 3795 ---
#
# --- Initial Configuration 3796 ---
#
# --- Initial Configuration 3797 ---
#
# --- Initial Configuration 3798 ---
#
# --- Initial Configuration 3799 ---
#
# --- Initial Configuration 3800 ---
#
# --- Initial Configuration 3801 ---
#
# --- Initial Configuration 3802 ---
#
# --- Initial Configuration 3803 ---
#
# --- Initial Configuration 3804 ---
#
# --- Initial Configuration 3805 ---
#
# --- Initial Configuration 3806 ---
#
# --- Initial Configuration 3807 ---
#
# --- Initial Configuration 3808 ---
#
# --- Initial Configuration 3809 ---
#
# --- Initial Configuration 3810 ---
#
# --- Initial Configuration 3811 ---
#
# --- Initial Configuration 3812 ---
#
# --- Initial Configuration 3813 ---
#
# --- Initial Configuration 3814 ---
#
# --- Initial Configuration 3815 ---
#
# --- Initial Configuration 3816 ---
#
# --- Initial Configuration 3817 ---
#
# --- Initial Configuration 3818 ---
#
# --- Initial Configuration 3819 ---
#
# --- Initial Configuration 3820 ---
#
# --- Initial Configuration 3821 ---
#
# --- Initial Configuration 3822 ---
#
# --- Initial Configuration 3823 ---
#
# --- Initial Configuration 3824 ---
#
# --- Initial Configuration 3825 ---
#
# --- Initial Configuration 3826 ---
#
# --- Initial Configuration 3827 ---
#
# --- Initial Configuration 3828 ---
#
# --- Initial Configuration 3829 ---
#
# --- Initial Configuration 3830 ---
#
# --- Initial Configuration 3831 ---
#
# --- Initial Configuration 3832 ---
#
# --- Initial Configuration 3833 ---
#
# --- Initial Configuration 3834 ---
#
# --- Initial Configuration 3835 ---
#
# --- Initial Configuration 3836 ---
#
# --- Initial Configuration 3837 ---
#
# --- Initial Configuration 3838 ---
#
# --- Initial Configuration 3839 ---
#
# --- Initial Configuration 3840 ---
#
# --- Initial Configuration 3841 ---
#
# --- Initial Configuration 3842 ---
#
# --- Initial Configuration 3843 ---
#
# --- Initial Configuration 3844 ---
#
# --- Initial Configuration 3845 ---
#
# --- Initial Configuration 3846 ---
#
# --- Initial Configuration 3847 ---
#
# --- Initial Configuration 3848 ---
#
# --- Initial Configuration 3849 ---
#
# --- Initial Configuration 3850 ---
#
# --- Initial Configuration 3851 ---
#
# --- Initial Configuration 3852 ---
#
# --- Initial Configuration 3853 ---
#
# --- Initial Configuration 3854 ---
#
# --- Initial Configuration 3855 ---
#
# --- Initial Configuration 3856 ---
#
# --- Initial Configuration 3857 ---
#
# --- Initial Configuration 3858 ---
#
# --- Initial Configuration 3859 ---
#
# --- Initial Configuration 3860 ---
#
# --- Initial Configuration 3861 ---
#
# --- Initial Configuration 3862 ---
#
# --- Initial Configuration 3863 ---
#
# --- Initial Configuration 3864 ---
#
# --- Initial Configuration 3865 ---
#
# --- Initial Configuration 3866 ---
#
# --- Initial Configuration 3867 ---
#
# --- Initial Configuration 3868 ---
#
# --- Initial Configuration 3869 ---
#
# --- Initial Configuration 3870 ---
#
# --- Initial Configuration 3871 ---
#
# --- Initial Configuration 3872 ---
#
# --- Initial Configuration 3873 ---
#
# --- Initial Configuration 3874 ---
#
# --- Initial Configuration 3875 ---
#
# --- Initial Configuration 3876 ---
#
# --- Initial Configuration 3877 ---
#
# --- Initial Configuration 3878 ---
#
# --- Initial Configuration 3879 ---
#
# --- Initial Configuration 3880 ---
#
# --- Initial Configuration 3881 ---
#
# --- Initial Configuration 3882 ---
#
# --- Initial Configuration 3883 ---
#
# --- Initial Configuration 3884 ---
#
# --- Initial Configuration 3885 ---
#
# --- Initial Configuration 3886 ---
#
# --- Initial Configuration 3887 ---
#
# --- Initial Configuration 3888 ---
#
# --- Initial Configuration 3889 ---
#
# --- Initial Configuration 3890 ---
#
# --- Initial Configuration 3891 ---
#
# --- Initial Configuration 3892 ---
#
# --- Initial Configuration 3893 ---
#
# --- Initial Configuration 3894 ---
#
# --- Initial Configuration 3895 ---
#
# --- Initial Configuration 3896 ---
#
# --- Initial Configuration 3897 ---
#
# --- Initial Configuration 3898 ---
#
# --- Initial Configuration 3899 ---
#
# --- Initial Configuration 3900 ---
#
# --- Initial Configuration 3901 ---
#
# --- Initial Configuration 3902 ---
#
# --- Initial Configuration 3903 ---
#
# --- Initial Configuration 3904 ---
#
# --- Initial Configuration 3905 ---
#
# --- Initial Configuration 3906 ---
#
# --- Initial Configuration 3907 ---
#
# --- Initial Configuration 3908 ---
#
# --- Initial Configuration 3909 ---
#
# --- Initial Configuration 3910 ---
#
# --- Initial Configuration 3911 ---
#
# --- Initial Configuration 3912 ---
#
# --- Initial Configuration 3913 ---
#
# --- Initial Configuration 3914 ---
#
# --- Initial Configuration 3915 ---
#
# --- Initial Configuration 3916 ---
#
# --- Initial Configuration 3917 ---
#
# --- Initial Configuration 3918 ---
#
# --- Initial Configuration 3919 ---
#
# --- Initial Configuration 3920 ---
#
# --- Initial Configuration 3921 ---
#
# --- Initial Configuration 3922 ---
#
# --- Initial Configuration 3923 ---
#
# --- Initial Configuration 3924 ---
#
# --- Initial Configuration 3925 ---
#
# --- Initial Configuration 3926 ---
#
# --- Initial Configuration 3927 ---
#
# --- Initial Configuration 3928 ---
#
# --- Initial Configuration 3929 ---
#
# --- Initial Configuration 3930 ---
#
# --- Initial Configuration 3931 ---
#
# --- Initial Configuration 3932 ---
#
# --- Initial Configuration 3933 ---
#
# --- Initial Configuration 3934 ---
#
# --- Initial Configuration 3935 ---
#
# --- Initial Configuration 3936 ---
#
# --- Initial Configuration 3937 ---
#
# --- Initial Configuration 3938 ---
#
# --- Initial Configuration 3939 ---
#
# --- Initial Configuration 3940 ---
#
# --- Initial Configuration 3941 ---
#
# --- Initial Configuration 3942 ---
#
# --- Initial Configuration 3943 ---
#
# --- Initial Configuration 3944 ---
#
# --- Initial Configuration 3945 ---
#
# --- Initial Configuration 3946 ---
#
# --- Initial Configuration 3947 ---
#
# --- Initial Configuration 3948 ---
#
# --- Initial Configuration 3949 ---
#
# --- Initial Configuration 3950 ---
#
# --- Initial Configuration 3951 ---
#
# --- Initial Configuration 3952 ---
#
# --- Initial Configuration 3953 ---
#
# --- Initial Configuration 3954 ---
#
# --- Initial Configuration 3955 ---
#
# --- Initial Configuration 3956 ---
#
# --- Initial Configuration 3957 ---
#
# --- Initial Configuration 3958 ---
#
# --- Initial Configuration 3959 ---
#
# --- Initial Configuration 3960 ---
#
# --- Initial Configuration 3961 ---
#
# --- Initial Configuration 3962 ---
#
# --- Initial Configuration 3963 ---
#
# --- Initial Configuration 3964 ---
#
# --- Initial Configuration 3965 ---
#
# --- Initial Configuration 3966 ---
#
# --- Initial Configuration 3967 ---
#
# --- Initial Configuration 3968 ---
#
# --- Initial Configuration 3969 ---
#
# --- Initial Configuration 3970 ---
#
# --- Initial Configuration 3971 ---
#
# --- Initial Configuration 3972 ---
#
# --- Initial Configuration 3973 ---
#
# --- Initial Configuration 3974 ---
#
# --- Initial Configuration 3975 ---
#
# --- Initial Configuration 3976 ---
#
# --- Initial Configuration 3977 ---
#
# --- Initial Configuration 3978 ---
#
# --- Initial Configuration 3979 ---
#
# --- Initial Configuration 3980 ---
#
# --- Initial Configuration 3981 ---
#
# --- Initial Configuration 3982 ---
#
# --- Initial Configuration 3983 ---
#
# --- Initial Configuration 3984 ---
#
# --- Initial Configuration 3985 ---
#
# --- Initial Configuration 3986 ---
#
# --- Initial Configuration 3987 ---
#
# --- Initial Configuration 3988 ---
#
# --- Initial Configuration 3989 ---
#
# --- Initial Configuration 3990 ---
#
# --- Initial Configuration 3991 ---
#
# --- Initial Configuration 3992 ---
#
# --- Initial Configuration 3993 ---
#
# --- Initial Configuration 3994 ---
#
# --- Initial Configuration 3995 ---
#
# --- Initial Configuration 3996 ---
#
# --- Initial Configuration 3997 ---
#
# --- Initial Configuration 3998 ---
#
# --- Initial Configuration 3999 ---
#
# --- Initial Configuration 4000 ---
#
# --- Initial Configuration 4001 ---
#
# --- Initial Configuration 4002 ---
#
# --- Initial Configuration 4003 ---
#
# --- Initial Configuration 4004 ---
#
# --- Initial Configuration 4005 ---
#
# --- Initial Configuration 4006 ---
#
# --- Initial Configuration 4007 ---
#
# --- Initial Configuration 4008 ---
#
# --- Initial Configuration 4009 ---
#
# --- Initial Configuration 4010 ---
#
# --- Initial Configuration 4011 ---
#
# --- Initial Configuration 4012 ---
#
# --- Initial Configuration 4013 ---
#
# --- Initial Configuration 4014 ---
#
# --- Initial Configuration 4015 ---
#
# --- Initial Configuration 4016 ---
#
# --- Initial Configuration 4017 ---
#
# --- Initial Configuration 4018 ---
#
# --- Initial Configuration 4019 ---
#
# --- Initial Configuration 4020 ---
#
# --- Initial Configuration 4021 ---
#
# --- Initial Configuration 4022 ---
#
# --- Initial Configuration 4023 ---
#
# --- Initial Configuration 4024 ---
#
# --- Initial Configuration 4025 ---
#
# --- Initial Configuration 4026 ---
#
# --- Initial Configuration 4027 ---
#
# --- Initial Configuration 4028 ---
#
# --- Initial Configuration 4029 ---
#
# --- Initial Configuration 4030 ---
#
# --- Initial Configuration 4031 ---
#
# --- Initial Configuration 4032 ---
#
# --- Initial Configuration 4033 ---
#
# --- Initial Configuration 4034 ---
#
# --- Initial Configuration 4035 ---
#
# --- Initial Configuration 4036 ---
#
# --- Initial Configuration 4037 ---
#
# --- Initial Configuration 4038 ---
#
# --- Initial Configuration 4039 ---
#
# --- Initial Configuration 4040 ---
#
# --- Initial Configuration 4041 ---
#
# --- Initial Configuration 4042 ---
#
# --- Initial Configuration 4043 ---
#
# --- Initial Configuration 4044 ---
#
# --- Initial Configuration 4045 ---
#
# --- Initial Configuration 4046 ---
#
# --- Initial Configuration 4047 ---
#
# --- Initial Configuration 4048 ---
#
# --- Initial Configuration 4049 ---
#
# --- Initial Configuration 4050 ---
#
# --- Initial Configuration 4051 ---
#
# --- Initial Configuration 4052 ---
#
# --- Initial Configuration 4053 ---
#
# --- Initial Configuration 4054 ---
#
# --- Initial Configuration 4055 ---
#
# --- Initial Configuration 4056 ---
#
# --- Initial Configuration 4057 ---
#
# --- Initial Configuration 4058 ---
#
# --- Initial Configuration 4059 ---
#
# --- Initial Configuration 4060 ---
#
# --- Initial Configuration 4061 ---
#
# --- Initial Configuration 4062 ---
#
# --- Initial Configuration 4063 ---
#
# --- Initial Configuration 4064 ---
#
# --- Initial Configuration 4065 ---
#
# --- Initial Configuration 4066 ---
#
# --- Initial Configuration 4067 ---
#
# --- Initial Configuration 4068 ---
#
# --- Initial Configuration 4069 ---
#
# --- Initial Configuration 4070 ---
#
# --- Initial Configuration 4071 ---
#
# --- Initial Configuration 4072 ---
#
# --- Initial Configuration 4073 ---
#
# --- Initial Configuration 4074 ---
#
# --- Initial Configuration 4075 ---
#
# --- Initial Configuration 4076 ---
#
# --- Initial Configuration 4077 ---
#
# --- Initial Configuration 4078 ---
#
# --- Initial Configuration 4079 ---
#
# --- Initial Configuration 4080 ---
#
# --- Initial Configuration 4081 ---
#
# --- Initial Configuration 4082 ---
#
# --- Initial Configuration 4083 ---
#
# --- Initial Configuration 4084 ---
#
# --- Initial Configuration 4085 ---
#
# --- Initial Configuration 4086 ---
#
# --- Initial Configuration 4087 ---
#
# --- Initial Configuration 4088 ---
#
# --- Initial Configuration 4089 ---
#
# --- Initial Configuration 4090 ---
#
# --- Initial Configuration 4091 ---
#
# --- Initial Configuration 4092 ---
#
# --- Initial Configuration 4093 ---
#
# --- Initial Configuration 4094 ---
#
# --- Initial Configuration 4095 ---
#
# --- Initial Configuration 4096 ---
#
# --- Final Summary over 1 Repeats of 1 Test Episodes ---
# success_rate: 0.61 +/- 0.0
# average_steps: 99.4 +/- 0.0
# average_reward: -490.32 +/- 0.0
# average_deviation_rate: 20.22 +/- 0.0

# %% [markdown]
# It can be observed that after 50,000 episodes of training, the model performs well on average across various randomised initial conditions, achieving Success Rate of 100, low Average Steps, high Average Reward and very marginal Average Deviation Rate from Optimal.

# %% [markdown]
# ***

# %% [markdown]
# ### 6. Visualisation
#
# The visualisation phase is implemented using the `matplotlib` library with the `TkAgg` backend, allowing for interactive and animated representations of the agent's behaviour in the grid world environment. This visualisation aims to show the performance of agents with different levels of training, assess their generalizability, and visually present the learning progress.
#
# ##### **Key components**
#
# 1. **Environment initialisation**:
#
# The `env.reset()` function initialises the environment for each new episode, randomly setting the initial positions of the agent and item, preparing for a new simulation. It also establishes initial values for `state`, `done`, `episode_steps`, and `episode_reward`.
#
# 2. **Initial setup**:
#
# Initial agent, item and target positions are printed, which provides context for the observer and serves as a benchmark for evaluating the agent's performance.
#
# 3. **Visualisation setup**:
#
# Functions like `ListedColormap()`, `plt.subplots()`, `ax.set_xticks()`, `ax.set_yticks()`, and `ax.grid()` are used to create and configure the figure object. Custom color maps and grid lines are set up to enhance visual clarity. The legend explains different grid states:
#
# - Letter `A` with Green backgroun: Agent
# - Letter `I` with Red background: Item
# - Letter `T` with Gray background: Target location
# - Text `A+I` with Cyan background: Agent carrying the item
# - Text `A at T (No I)` with Magenta backgroun: Agent at target location without the item
# - Text `A+I at T` with Orange background: Agent at target location with the item
#
# 4. **Animation function**:
#
# The internal function `animate(i)` updates each frame of the visualisation. It calls `agent.choose_action(state)` and `env.step(action)` to show the agent's real-time decision-making process. It uses `ax.imshow()` to update the grid state and `ax.text()` to add annotations for different elements (agent, item, target). The function employs complex conditional logic to update grid states, reflecting different scenarios (e.g., agent carrying item, reaching target). It also prints detailed step information for in-depth analysis.
#
# 5. **Animation creation and display**:
#
# The visualisation process is implemented using `FuncAnimation()` to create an animated representation of the agent's behavior. This animation is displayed using `plt.show()`. To ensure the visualisation remains manageable and informative, we use a maximum step limit `(max_steps=25)`, which serves three crucial purposes:
#
# - It prevents the visualisation from running indefinitely if the agent is stuck in a loop.
# - It simulates real-world constraints where tasks often have time or resource limitations.
# - It provides a clear metric for improvement: as training progresses, the agent should complete the task within this limit more consistently.
#
# **Two possible scenarios:**<br>
#
# 1. Task Not Completed (Failure Case):
#
# If the maximum step limit is reached without task completion:
# A `red` text annotation appears on the plot: "Failed to complete within `max_steps` step limit!"
#
# 2. Task Completed Successfully:
#
# A `blue` text annotation is added to the plot: "Successfully completed the task with deviation from the optimal path by `deviation` step(s)!"
#
# After each visulisation, comprehensive summary is printed, detailing:
#
# - Number of steps taken
# - Optimal step count
# - Total reward accumulated
# - Deviation from the optimal path

# %%
# # Function to visualise one episode using the trained agent
# def visualise_episode(agent, env, cumulative_episodes, interval=500, max_steps=25):
#     # Reset the environment to start a new episode
#     state = env.reset()
#     done = False
#     episode_steps = 0
#     episode_reward = 0

#     # Capture initial positions for printing
#     initial_agent_location = state[:2]
#     initial_item_location = state[2:4]
#     drop_off_location = state[4:6]

#     # Calculate theoretical shortest path or optimal steps
#     optimal_steps_to_item = manhattan_distance(initial_agent_location, initial_item_location)
#     optimal_steps_to_target = manhattan_distance(initial_item_location, drop_off_location)
#     optimal_steps = optimal_steps_to_item + optimal_steps_to_target
    
#     # Print the initial locations and episode information
#     print(f"Initial Agent Location: {initial_agent_location}")
#     print(f"Initial Item Location (A): {initial_item_location}")
#     print(f"Drop-Off Location (B): {drop_off_location}")

#     # Define a custom colormap
#     cmap = ListedColormap(['white', 'green', 'red', 'gray', 'cyan', 'magenta', 'orange'])

#     # Create the figure for visualisation
#     fig, ax = plt.subplots(figsize=(9, 6))
#     ax.set_xticks(np.arange(-0.5, env.size, 1))
#     ax.set_yticks(np.arange(-0.5, env.size, 1))
#     ax.set_xticklabels([])
#     ax.set_yticklabels([])
#     ax.grid(True, color='black')  # Set grid lines to black
#     ax.set_aspect('equal')

#     # Set the background color to white
#     ax.set_facecolor('white')

#     # Add a title to the figure
#     fig.suptitle(f'Grid World - Trained {cumulative_episodes} Episodes', fontsize=16)

#     # Define the legend patches
#     legend_patches = [
#         mpatches.Patch(color='green', label='A - Agent'),
#         mpatches.Patch(color='red', label='I - Item'),
#         mpatches.Patch(color='gray', label='T - Target'),
#         mpatches.Patch(color='cyan', label='A+I'),
#         mpatches.Patch(color='magenta', label='A at T (No I)'),
#         mpatches.Patch(color='orange', label='A+I at T'),
#     ]

#     # Animate the grid world for each step in the episode
#     def animate(i):
#         # Access the nonlocal variables to update them
#         nonlocal state, episode_steps, done, episode_reward

#         # Display the initial state before starting the episode
#         if i == 0:
#             agent_pos, item_pos, has_item = state[:2], state[2:4], state[-1]

#             grid = np.zeros((env.size, env.size))
#             grid[tuple(agent_pos)] = 1
#             grid[tuple(item_pos)] = 2
#             grid[env.target_location] = 3

#             ax.imshow(grid, cmap=cmap, vmin=0, vmax=6)

#             # Annotate the grid with labels but no color changes
#             for (j, i), label in np.ndenumerate(grid):
#                 if label == 1: # Agent location only
#                     ax.text(i, j, 'A', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
#                 elif label == 2: # Item location only
#                     ax.text(i, j, 'I', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
#                 elif label == 3: # Target location only
#                     ax.text(i, j, 'T', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
            
#             # Reapply the legend after clearing
#             ax.legend(handles=legend_patches, loc='center right', bbox_to_anchor=(1.36, 0.85), fontsize='11')

#             return

#         # Continue the episode if the task is not finished
#         if not done:
#             # Select the action and perform the step in the environment
#             action = agent.get_action(state)
#             next_state, reward, done = env.step(action)

#             episode_steps += 1
#             episode_reward += reward
#             state = next_state

#             # Print the step details (optional)
#             # print(f"Step {episode_steps}: Action = {action}, Reward = {reward}, New State = {next_state}")

#             # Create the grid to visualise
#             grid = np.zeros((env.size, env.size))
#             agent_pos, item_pos, has_item = next_state[:2], next_state[2:4], next_state[-1]

#             # Update the grid colors based on the current state
#             if not has_item and tuple(agent_pos) != env.target_location:
#                 grid[tuple(agent_pos)] = 1
#                 grid[tuple(item_pos)] = 2
#                 grid[env.target_location] = 3
#             elif not has_item and tuple(agent_pos) == env.target_location:
#                 grid[tuple(item_pos)] = 2
#                 grid[env.target_location] = 5
#             elif has_item and tuple(agent_pos) != env.target_location:
#                 grid[tuple(agent_pos)] = 4
#                 grid[env.target_location] = 3
#             elif has_item and tuple(agent_pos) == env.target_location:
#                 grid[env.target_location] = 6

#             ax.clear()
#             ax.imshow(grid, cmap=cmap, vmin=0, vmax=6)

#             # Reapply grid lines and labels after clearing
#             ax.set_xticks(np.arange(-0.5, env.size, 1))
#             ax.set_yticks(np.arange(-0.5, env.size, 1))
#             ax.set_xticklabels([])
#             ax.set_yticklabels([])
#             ax.grid(True, color='black')  # Set grid lines to black
#             ax.set_facecolor('white')  # Set background color to white

#             # Annotate the grid with labels but no color changes
#             for (j, i), label in np.ndenumerate(grid):
#                 if label == 1: # Agent location only
#                     ax.text(i, j, 'A', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
#                 elif label == 2: # Item location only
#                     ax.text(i, j, 'I', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
#                 elif label == 3: # Target location only
#                     ax.text(i, j, 'T', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
#                 elif label == 4: # Agent location with item
#                     ax.text(i, j, 'A+I', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
#                 elif label == 5: # Target location with agent but without item
#                     ax.text(i, j, 'A at T (No I)', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
#                 elif label == 6: # Target location with agent and item
#                     ax.text(i, j, 'A+I at T', ha='center', va='center', color='black', fontsize=11, fontweight='bold')

#             # Reapply the legend after clearing
#             ax.legend(handles=legend_patches, loc='center right', bbox_to_anchor=(1.36, 0.85), fontsize='11')

#         # Stop the animation if the task is finished or the maximum steps are reached
#         if done or episode_steps == max_steps:  
#             deviation = episode_steps - optimal_steps
#             if episode_steps == max_steps:
#                 print(f"*** After {cumulative_episodes} episodes of training, agent did not complete the task within {max_steps} steps.\n")
#                 # Annotate the "Failed" case on the plot
#                 ax.text(0.5, 0.5, f'Failed to complete within {max_steps} step limit !', 
#                         ha='center', va='center', transform=ax.transAxes, 
#                         fontsize=20, color='red', fontweight='bold',
#                         bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))
#             elif done:
#                 # Print the summary of the episode
#                 # Annotate the "Successful" case on the plot
#                 ax.text(0.5, 0.5, f'Successfully completed the task with\n deviation from the optimal path by {deviation} step(s) !'.format(episode_steps),
#                         ha='center', va='center', transform=ax.transAxes, 
#                         fontsize=20, color='blue', fontweight='bold',
#                         bbox=dict(facecolor='white', alpha=0.8, edgecolor='blue'))
#                 print(f"*** After {cumulative_episodes} episodes of training, agent completed the task.")
#                 print(f"Summary: Steps = {episode_steps} (Optimal Steps = {optimal_steps}), Total Reward = {episode_reward}, Deviation from Optimal: {deviation}\n")

#             anim.event_source.stop()  # Stop the animation when done
#             plt.draw()  # Force a draw of the current figure to ensure the last frame is rendered

#             plt.pause(2)  # Short pause to ensure the rendering occurs
#             plt.close(fig)  # Automatically close the figure window

#     # Create the animation
#     anim = FuncAnimation(fig, animate, interval=interval, frames=100) 

#     plt.show()

# %%
# Function to visualise one episode using the trained agent with step limit
def visualise_episode(agent, env, cumulative_episodes, interval=500, step_limit=25):
    # Reset the environment to start a new episode
    state = env.reset()
    done = False
    episode_steps = 0
    episode_reward = 0

    # Capture initial positions for printing
    initial_agent_location = state[:2]
    initial_item_location = state[2:4]
    drop_off_location = state[4:6]

    # Calculate theoretical shortest path or optimal steps
    optimal_steps_to_item = manhattan_distance(initial_agent_location, initial_item_location)
    optimal_steps_to_target = manhattan_distance(initial_item_location, drop_off_location)
    optimal_steps = optimal_steps_to_item + optimal_steps_to_target
    
    # Print the initial locations and episode information
    print(f"Initial Agent Location: {initial_agent_location}")
    print(f"Initial Item Location (A): {initial_item_location}")
    print(f"Drop-Off Location (B): {drop_off_location}")

    # Define a custom colormap
    cmap = ListedColormap(['white', 'green', 'red', 'gray', 'cyan', 'magenta', 'orange'])

    # Create the figure for visualisation
    fig, ax = plt.subplots(figsize=(9, 6))
    ax.set_xticks(np.arange(-0.5, env.size, 1))
    ax.set_yticks(np.arange(-0.5, env.size, 1))
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(True, color='black')  # Set grid lines to black
    ax.set_aspect('equal')

    # Set the background color to white
    ax.set_facecolor('white')

    # Add a title to the figure
    fig.suptitle(f'Grid World - Trained {cumulative_episodes} Episodes', fontsize=16)

    # Define the legend patches
    legend_patches = [
        mpatches.Patch(color='green', label='A - Agent'),
        mpatches.Patch(color='red', label='I - Item'),
        mpatches.Patch(color='gray', label='T - Target'),
        mpatches.Patch(color='cyan', label='A+I'),
        mpatches.Patch(color='magenta', label='A at T (No I)'),
        mpatches.Patch(color='orange', label='A+I at T'),
    ]

    # Animate the grid world for each step in the episode
    def animate(i):
        # Access the nonlocal variables to update them
        nonlocal state, episode_steps, done, episode_reward

        # Display the initial state before starting the episode
        if i == 0:
            agent_pos, item_pos, has_item = state[:2], state[2:4], state[-1]

            grid = np.zeros((env.size, env.size))
            grid[tuple(agent_pos)] = 1
            grid[tuple(item_pos)] = 2
            grid[env.target_location] = 3

            ax.imshow(grid, cmap=cmap, vmin=0, vmax=6)

            # Annotate the grid with labels but no color changes
            for (j, i), label in np.ndenumerate(grid):
                if label == 1:  # Agent location only
                    ax.text(i, j, 'A', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
                elif label == 2:  # Item location only
                    ax.text(i, j, 'I', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
                elif label == 3:  # Target location only
                    ax.text(i, j, 'T', ha='center', va='center', color='black', fontsize=11, fontweight='bold')

            # Reapply the legend after clearing
            ax.legend(handles=legend_patches, loc='center right', bbox_to_anchor=(1.36, 0.85), fontsize='11')

            return

        # Continue the episode if the task is not finished and step limit is not reached
        if not done and episode_steps < step_limit:
            # Select the action and perform the step in the environment
            action = agent.get_action(state)
            next_state, reward, done = env.step(action)

            episode_steps += 1
            episode_reward += reward
            state = next_state

            # Create the grid to visualise
            grid = np.zeros((env.size, env.size))
            agent_pos, item_pos, has_item = next_state[:2], next_state[2:4], next_state[-1]

            # Update the grid colors based on the current state
            if not has_item and tuple(agent_pos) != env.target_location:
                grid[tuple(agent_pos)] = 1
                grid[tuple(item_pos)] = 2
                grid[env.target_location] = 3
            elif not has_item and tuple(agent_pos) == env.target_location:
                grid[tuple(item_pos)] = 2
                grid[env.target_location] = 5
            elif has_item and tuple(agent_pos) != env.target_location:
                grid[tuple(agent_pos)] = 4
                grid[env.target_location] = 3
            elif has_item and tuple(agent_pos) == env.target_location:
                grid[env.target_location] = 6

            ax.clear()
            ax.imshow(grid, cmap=cmap, vmin=0, vmax=6)

            # Reapply grid lines and labels after clearing
            ax.set_xticks(np.arange(-0.5, env.size, 1))
            ax.set_yticks(np.arange(-0.5, env.size, 1))
            ax.set_xticklabels([])
            ax.set_yticklabels([])
            ax.grid(True, color='black')  # Set grid lines to black
            ax.set_facecolor('white')  # Set background color to white

            # Annotate the grid with labels but no color changes
            for (j, i), label in np.ndenumerate(grid):
                if label == 1:  # Agent location only
                    ax.text(i, j, 'A', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
                elif label == 2:  # Item location only
                    ax.text(i, j, 'I', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
                elif label == 3:  # Target location only
                    ax.text(i, j, 'T', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
                elif label == 4:  # Agent location with item
                    ax.text(i, j, 'A+I', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
                elif label == 5:  # Target location with agent but without item
                    ax.text(i, j, 'A at T (No I)', ha='center', va='center', color='black', fontsize=11, fontweight='bold')
                elif label == 6:  # Target location with agent and item
                    ax.text(i, j, 'A+I at T', ha='center', va='center', color='black', fontsize=11, fontweight='bold')

            # Reapply the legend after clearing
            ax.legend(handles=legend_patches, loc='center right', bbox_to_anchor=(1.36, 0.85), fontsize='11')

        # Stop the animation if the task is finished or the maximum steps are reached
        if done or episode_steps == step_limit:
            deviation = episode_steps - optimal_steps
            if episode_steps == step_limit:
                print(f"*** After {cumulative_episodes} episodes of training, agent did not complete the task within {step_limit} steps.\n")
                # Annotate the "Failed" case on the plot
                ax.text(0.5, 0.5, f'Failed to complete within {step_limit} step limit !', 
                        ha='center', va='center', transform=ax.transAxes, 
                        fontsize=20, color='red', fontweight='bold',
                        bbox=dict(facecolor='white', alpha=0.8, edgecolor='red'))
            elif done:
                # Print the summary of the episode
                # Annotate the "Successful" case on the plot
                ax.text(0.5, 0.5, f'Successfully completed the task with\n deviation from the optimal path by {deviation} step(s) !'.format(episode_steps),
                        ha='center', va='center', transform=ax.transAxes, 
                        fontsize=20, color='blue', fontweight='bold',
                        bbox=dict(facecolor='white', alpha=0.8, edgecolor='blue'))
                print(f"*** After {cumulative_episodes} episodes of training, agent completed the task.")
                print(f"Summary: Steps = {episode_steps} (Optimal Steps = {optimal_steps}), Total Reward = {episode_reward}, Deviation from Optimal: {deviation}\n")

            anim.event_source.stop()  # Stop the animation when done
            plt.draw()  # Force a draw of the current figure to ensure the last frame is rendered

            plt.pause(2)  # Short pause to ensure the rendering occurs
            plt.close(fig)  # Automatically close the figure window

    # Create the animation
    anim = FuncAnimation(fig, animate, interval=interval, frames=100)

    plt.show()

# %% [markdown]
# **Examples of effects of different training episodes**
#
# We use random initialisations for each test to evaluate the agent's ability to generalize. By randomly setting the initial positions of the agent and item for each visualisation, we ensure that the agent's performance is tested across various scenarios, not just those it encountered during training. This approach helps assess whether the agent has learned general strategies or merely memorized specific paths.
#
# Progressive improvement with increased training:
#
# As the number of training episodes increases, we observe a clear progression in the agent's performance:
#
# - Exploratory stage (~ 100 episodes):
#
# The agent is in the initial phase, exploring the environment with minimal learned behavior. The agent often fails to complete the task within the maximum step limit (25 steps). Movements appear random or inefficient, indicating insufficient learning.
#
# - Adaptive stage (~ 500 episodes):
#
# The agent begins to adapt to the environment, showing early signs of learning but with inconsistent performance.  It might complete simpler configurations but fail in more complex scenarios.
#
# - Proficient stage (~ 1000 episodes):
#
# The agent is now more proficient, often completing tasks, though not always optimally. It shows more purposeful movements, suggesting improved learning.
#
# - Optimising stage (~ 2500 episodes):
#
# The agent is refining its strategies, consistently completing tasks with greater efficiency and fewer errors. Deviations from the optimal steps are smaller and less frequent.<br>
#
# - Mastery stage (~ 5000 episodes):
#
# The agent demonstrates mastery, achieving tasks with high efficiency and minimal deviations from the optimal steps. It efficiently navigates to the item and then to the target location, demonstrating well-developed strategies. The performance across random initialisations is consistently high, indicating good generalisability.
#
# This visualisation approach demonstrates the gradual improvement in the agent's performance across a wider range of training episodes. It highlights the agent's ability to generalise learned strategies to unseen situations, demonstrating the progression from failing to complete the task, to completing it sub-optimally, and finally to near-optimal completion across random scenarios. This comprehensive view allows us to observe the improvements at each stage of training, providing insights into the learning dynamics of the Q-learning algorithm in this grid world environment.

# %%
# # Visualise trained agent at different training levels

# # training progression list, e.g. first train for 100 episodes, then an additional 150 episodes
# # with a total of 250 episodes, then an addtional 250 episodes with a total of 500 episodes, and so on
# # This is equivalent to test an agent at different training levels of 100, 250, 500, 750, and 1000 episodes.

# #episodes_progression_list = [50, 50, 50, 50, 50]
# episodes_progression_list = [100, 150, 250, 250, 250]

# # Initialise the environment and agent
# env = GridWorld(size=4)
# state_size = 11  # (y,x) for agent, item, target + directions + possession status
# action_size = 4  # Four possible actions (north, south, west, east)
# agent = DeepQAgent(state_size=state_size, action_size=action_size)
# cumulative_episodes = 0

# for episode in episodes_progression_list:
#     cumulative_episodes += episode
#     train_agent(agent, env, episode)
#     print(f"--- After {cumulative_episodes} Training Episodes Test Visualisation and Summary---")
    
#     visualise_episode(agent, env, cumulative_episodes)
# Out:
# --- After 100 Training Episodes Test Visualisation and Summary---
# Initial Agent Location: (4, 1)
# Initial Item Location (A): (3, 4)
# Drop-Off Location (B): (4, 4)
# Step 1: Action = north, Reward = -1, New State = ((3, 1), (3, 4), False)
# Step 2: Action = north, Reward = -1, New State = ((2, 1), (3, 4), False)
# Step 3: Action = east, Reward = -1, New State = ((2, 2), (3, 4), False)
# Step 4: Action = south, Reward = -1, New State = ((3, 2), (3, 4), False)
# Step 5: Action = north, Reward = -1, New State = ((2, 2), (3, 4), False)
# Step 6: Action = east, Reward = -1, New State = ((2, 3), (3, 4), False)
# Step 7: Action = south, Reward = -1, New State = ((3, 3), (3, 4), False)
# Step 8: Action = south, Reward = -1, New State = ((4, 3), (3, 4), False)
# Step 9: Action = west, Reward = -1, New State = ((4, 2), (3, 4), False)
# Step 10: Action = north, Reward = -1, New State = ((3, 2), (3, 4), False)
# Step 11: Action = west, Reward = -1, New State = ((3, 1), (3, 4), False)
# Step 12: Action = south, Reward = -1, New State = ((4, 1), (3, 4), False)
# Step 13: Action = west, Reward = -1, New State = ((4, 0), (3, 4), False)
# Step 14: Action = north, Reward = -1, New State = ((3, 0), (3, 4), False)
# Step 15: Action = east, Reward = -1, New State = ((3, 1), (3, 4), False)
# Step 16: Action = north, Reward = -1, New State = ((2, 1), (3, 4), False)
# Step 17: Action = west, Reward = -1, New State = ((2, 0), (3, 4), False)
# Step 18: Action = east, Reward = -1, New State = ((2, 1), (3, 4), False)
# Step 19: Action = south, Reward = -1, New State = ((3, 1), (3, 4), False)
# Step 20: Action = north, Reward = -1, New State = ((2, 1), (3, 4), False)
# Step 21: Action = east, Reward = -1, New State = ((2, 2), (3, 4), False)
# Step 22: Action = south, Reward = -1, New State = ((3, 2), (3, 4), False)
# Step 23: Action = south, Reward = -1, New State = ((4, 2), (3, 4), False)
# Step 24: Action = west, Reward = -1, New State = ((4, 1), (3, 4), False)
# Step 25: Action = north, Reward = -1, New State = ((3, 1), (3, 4), False)
# *** After 100 episodes of training, agent did not complete the task within 25 steps.
#
# --- After 500 Training Episodes Test Visualisation and Summary---
# Initial Agent Location: (0, 2)
# Initial Item Location (A): (1, 0)
# Drop-Off Location (B): (4, 4)
# Step 1: Action = south, Reward = -1, New State = ((1, 2), (1, 0), False)
# Step 2: Action = east, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 3: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 4: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 5: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 6: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 7: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 8: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 9: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 10: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 11: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 12: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 13: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 14: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 15: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 16: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 17: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 18: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 19: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 20: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 21: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 22: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 23: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# Step 24: Action = west, Reward = -1, New State = ((1, 3), (1, 0), False)
# Step 25: Action = east, Reward = -1, New State = ((1, 4), (1, 0), False)
# *** After 500 episodes of training, agent did not complete the task within 25 steps.
#
# --- After 1000 Training Episodes Test Visualisation and Summary---
# Initial Agent Location: (4, 1)
# Initial Item Location (A): (1, 2)
# Drop-Off Location (B): (4, 4)
# Step 1: Action = west, Reward = -1, New State = ((4, 0), (1, 2), False)
# Step 2: Action = north, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 3: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 4: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 5: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 6: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 7: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 8: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 9: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 10: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 11: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 12: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 13: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 14: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 15: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 16: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 17: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 18: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 19: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 20: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 21: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 22: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 23: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# Step 24: Action = west, Reward = -1, New State = ((3, 0), (1, 2), False)
# Step 25: Action = east, Reward = -1, New State = ((3, 1), (1, 2), False)
# *** After 1000 episodes of training, agent did not complete the task within 25 steps.
#
# --- After 2500 Training Episodes Test Visualisation and Summary---
# Initial Agent Location: (3, 2)
# Initial Item Location (A): (0, 1)
# Drop-Off Location (B): (4, 4)
# Step 1: Action = west, Reward = -1, New State = ((3, 1), (0, 1), False)
# Step 2: Action = north, Reward = -1, New State = ((2, 1), (0, 1), False)
# Step 3: Action = north, Reward = -1, New State = ((1, 1), (0, 1), False)
# Step 4: Action = north, Reward = -1, New State = ((0, 1), (0, 1), True)
# Step 5: Action = east, Reward = -1, New State = ((0, 2), (0, 1), True)
# Step 6: Action = east, Reward = -1, New State = ((0, 3), (0, 1), True)
# Step 7: Action = south, Reward = -1, New State = ((1, 3), (0, 1), True)
# Step 8: Action = east, Reward = -1, New State = ((1, 4), (0, 1), True)
# Step 9: Action = south, Reward = -1, New State = ((2, 4), (0, 1), True)
# Step 10: Action = south, Reward = -1, New State = ((3, 4), (0, 1), True)
# Step 11: Action = south, Reward = 100, New State = ((4, 4), (0, 1), True)
# *** After 2500 episodes of training, agent completed the task.
# Summary: Steps = 11 (Optimal Steps = 11), Total Reward = 90, Deviation from Optimal: 0
#
# --- After 5000 Training Episodes Test Visualisation and Summary---
# Initial Agent Location: (0, 1)
# Initial Item Location (A): (4, 3)
# Drop-Off Location (B): (4, 4)
# Step 1: Action = south, Reward = -1, New State = ((1, 1), (4, 3), False)
# Step 2: Action = south, Reward = -1, New State = ((2, 1), (4, 3), False)
# Step 3: Action = east, Reward = -1, New State = ((2, 2), (4, 3), False)
# Step 4: Action = south, Reward = -1, New State = ((3, 2), (4, 3), False)
# Step 5: Action = south, Reward = -1, New State = ((4, 2), (4, 3), False)
# Step 6: Action = east, Reward = -1, New State = ((4, 3), (4, 3), True)
# Step 7: Action = east, Reward = 100, New State = ((4, 4), (4, 3), True)
# *** After 5000 episodes of training, agent completed the task.
# Summary: Steps = 7 (Optimal Steps = 7), Total Reward = 94, Deviation from Optimal: 0

# %% [markdown]
# ***

# %%
# Visualise trained agent at different training levels with step limit

# training progression list, e.g. first train for 100 episodes, then an additional 150 episodes
# with a total of 250 episodes, then an additional 250 episodes with a total of 500 episodes, and so on
# This is equivalent to test an agent at different training levels of 100, 250, 500, 750, and 1000 episodes.

# episodes_progression_list = [50, 50, 50, 50, 50]
episodes_progression_list = [100, 150, 250, 250, 250]
step_limit = 25  # Define the step limit based on the environment's size and constraints

# Initialise the environment and agent
env = GridWorld(size=4)
state_size = 11  # (y,x) for agent, item, target + directions + possession status
action_size = 4  # Four possible actions (north, south, west, east)
agent = DeepQAgent(state_size=state_size, action_size=action_size)
cumulative_episodes = 0

for episode in episodes_progression_list:
    cumulative_episodes += episode
    train_agent(agent, env, episode, max_steps=step_limit)  # Pass step_limit to the training function
    print(f"--- After {cumulative_episodes} Training Episodes Test Visualisation and Summary ---")
    
    visualise_episode(agent, env, cumulative_episodes, step_limit=step_limit)  # Pass step_limit to the visualisation function

# %% [markdown]
# ### 7. Conclusion and Limitations

# %% [markdown]
# In this project, we successfully implemented a tabular Q-learning agent to navigate a grid world environment. The agent’s task was to locate a randomly positioned item and deliver it to a fixed target location, optimising the number of steps taken. Through iterative development and testing, we crafted a reward structure that effectively guided the agent’s learning process, allowing it to generalize across various initial conditions. The results demonstrate that our agent efficiently learned to perform the task, achieving high performance across different scenarios. The visualisations provided clearly illustrated the agent’s learning progression, further validating our approach.
#
# While our implementation effectively accomplished the task, several limitations were identified. The primary limitation is the scalability of tabular Q-learning. As the grid size increases, the state-action space expands exponentially, making it computationally intensive to manage the Q-table. This limitation also constrains the agent’s ability to learn in more complex environments that require finer granularity in state representation.
#
# Additionally, the agent’s learning efficiency is highly dependent on the reward structure and hyperparameters such as the learning rate and exploration strategy. Optimising these parameters requires extensive experimentation, which may not always be feasible in more complex environment settings.
#
# Moreover, the fixed nature of the grid world and the simplicity of the task do not fully reflect the challenges encountered in real-world applications. Addressing dynamic environments, obstacles, and more sophisticated task objectives would require advanced techniques, such as deep learning-based function approximation, which are beyond the scope of tabular Q-learning.
#
# Overall, this stage of the project laid a strong foundation for further exploration in reinforcement learning. The insights gained here will be invaluable as we transition to more complex environments and learning paradigms in subsequent stages. Our results underscore the potential of tabular Q-learning as a robust method for solving pathfinding and optimisation problems in grid-based environments, despite its limitations.

# %% [markdown]
# ### 8. Acknowledgement

# %% [markdown]
# We utilised ChatGPT (OpenAI, 2024) to summarise the code and review the grammar in our work. The output was subsequently adjusted to better align with our writing style.

# %% [markdown]
# ### 9. References

# %% [markdown]
# OpenAI. (2024). ChatGPT (Version 1.2024.227) [Large language model]. https://chatgpt.com/
